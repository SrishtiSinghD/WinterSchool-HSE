# %% [markdown]
# # **PARSING OF JIRA BUG TICKETS FOR APACHE OPEN-SOURCE PROJECT**

# %% [markdown]
# ## WEBSCRAPPING APACHE PROJECT BUG TICKETS DATA
#
# The data about bugs in the Apache project is fetched Apache's JIRA issue tracker using jira api.

# %% [markdown]
# ## Findings about fetched data
# 1. It is in json format which is equivalent of dictionary in python
# 2. The fetched data has 5 fields/keys [***Label1***]:<br>
#     a. expand: It is a string<br>
#     b. startAt: starting index<br>
#     c. maxResults: Maximum requests that can be read<br>
#        Note: maxResults is equal to pagelength given in code but it's maximum value can be 1000
#     d. total: Gives total number of issues in the tracker<br>
#        Note: It can be greater than the number of maxResults that can be fetched via api in one request
#        (e.g. In the case of Apache airflow)
#     e. issues: It is a list of issues in json form/dictionary form

# %%
#Importing the requests module
import requests

#Base url
jira_api_base_url = "https://issues.apache.org/jira/"

#max number of results fetched per request
page_length = 1000

#name of project
project = "airflow"
proj_jira_id = project.upper()

#starting index
start_idx = 0

#Dictionary to store fetched results
r_dict={}

"""
Intially we don't know what are the total number of issues in the JIRA Isuue
Tracker for a single project, 
so we set it to 0"""
total=0

"""
To know the total number issues, we need to pull request from the url atleast once

One can do it in many ways, but here do-while loop is used

Since, python doesn't support do-while loops
Below is given one way to mimic the do-while loop in python 
"""
while True:
  #Making the final url
  url = (
      jira_api_base_url
      + f"rest/api/2/search?jql=project={proj_jira_id}+order+by+created"
      + f"&issuetypeNames=Bug&maxResults={page_length}&"
      + f"startAt={start_idx}&fields=id,key,priority,labels,versions,"
      + "status,components,creator,reporter,issuetype,description,"
      + "summary,resolutiondate,created,updated"
  )

  #Printing the final url from where the data is fetched
  print(f"Getting data from {url}...")

  #Sends a GET request to fetch data from specified url
  r = requests.get(url)

  #Storing the json data fetched from the url in a temporary dictionary
  #You can refer to "Label1" in the above cell for reviewing the structure of the json data fetched
  temp_dict = r.json()

  #Increasing the start index of request by a value
  """
  That value is equal to the page length as we have already fetched the specified number of pages
  """
  start_idx+=page_length

  #Making total equal to the total number of issues present in the tracker
  total=temp_dict['total']

  #Intially our result dictionary is empty
  #So we can check if it's empty using the length command --> len 
  if len(r_dict)==0:
    #Copying temporary fetched dictionary to our empty result dictionary
    r_dict=temp_dict.copy()

  #If it is not empty then
  #We just need to add the fetched list of 'issues'
  #from temporary dictionary(temp_dict) to our final result dictionary(r_dict)
  else:
    #Adding two lists using the extend function
    r_dict['issues'].extend(temp_dict['issues'])

  #Now condition of while is checked
  #If the start index has exceeded the total issues the loop will break
  if total<start_idx:
    break
# Out:
# Getting data from https://issues.apache.org/jira/rest/api/2/search?jql=project=AIRFLOW+order+by+created&issuetypeNames=Bug&maxResults=1000&startAt=0&fields=id,key,priority,labels,versions,status,components,creator,reporter,issuetype,description,summary,resolutiondate,created,updated...
# Getting data from https://issues.apache.org/jira/rest/api/2/search?jql=project=AIRFLOW+order+by+created&issuetypeNames=Bug&maxResults=1000&startAt=1000&fields=id,key,priority,labels,versions,status,components,creator,reporter,issuetype,description,summary,resolutiondate,created,updated...
# Getting data from https://issues.apache.org/jira/rest/api/2/search?jql=project=AIRFLOW+order+by+created&issuetypeNames=Bug&maxResults=1000&startAt=2000&fields=id,key,priority,labels,versions,status,components,creator,reporter,issuetype,description,summary,resolutiondate,created,updated...
# Getting data from https://issues.apache.org/jira/rest/api/2/search?jql=project=AIRFLOW+order+by+created&issuetypeNames=Bug&maxResults=1000&startAt=3000&fields=id,key,priority,labels,versions,status,components,creator,reporter,issuetype,description,summary,resolutiondate,created,updated...
# Getting data from https://issues.apache.org/jira/rest/api/2/search?jql=project=AIRFLOW+order+by+created&issuetypeNames=Bug&maxResults=1000&startAt=4000&fields=id,key,priority,labels,versions,status,components,creator,reporter,issuetype,description,summary,resolutiondate,created,updated...
# Getting data from https://issues.apache.org/jira/rest/api/2/search?jql=project=AIRFLOW+order+by+created&issuetypeNames=Bug&maxResults=1000&startAt=5000&fields=id,key,priority,labels,versions,status,components,creator,reporter,issuetype,description,summary,resolutiondate,created,updated...
# Getting data from https://issues.apache.org/jira/rest/api/2/search?jql=project=AIRFLOW+order+by+created&issuetypeNames=Bug&maxResults=1000&startAt=6000&fields=id,key,priority,labels,versions,status,components,creator,reporter,issuetype,description,summary,resolutiondate,created,updated...
# Getting data from https://issues.apache.org/jira/rest/api/2/search?jql=project=AIRFLOW+order+by+created&issuetypeNames=Bug&maxResults=1000&startAt=7000&fields=id,key,priority,labels,versions,status,components,creator,reporter,issuetype,description,summary,resolutiondate,created,updated...

# %%
#Checking the maximum number of results fetched per request
r_dict['maxResults']
# Out:
# 1000

# %%
#Total number of issues in the Tracker
r_dict['total']
# Out:
# 7038

# %%
#Checking the length of issues in our final dictionary(r_dict) to make sure it is equal to total number of issues in the tracker
len(r_dict['issues'])
# Out:
# 7038

# %% [markdown]
# ## COLLECTION OF RELEVANT DATA
# According to the columns suggested in the [sample](https://github.com/HelgeCPH/ase-effect-branching-on-defects/blob/master/data/samples/airflow_interface.csv) interface by [HelgeCPH](https://github.com/HelgeCPH/)
#
# We need to extract 5 information from our dictionary(r_dict)
# The five columns are as follows:<br>
#     1. key<br>
#     2. priority<br>
#     3. created<br>
#     4. status<br>
#     5. versions

# %%
#Empty list to store our data
data=[]

# %%
#For each issue in the total issues , we will collect five items(namely: key,priority,created,status,versions)
for issue in r_dict['issues']:
  #List to store data for one row/issue
  row=[]

  #Getting the key value
  key=issue['key']

  #Getting priority name
  priority=issue['fields']['priority']['name']

  #Getting the date and time when issue was created
  created=issue['fields']['created']

  #Getting the name of status of the issue(e.g. Open,Closed,Resolved)
  status=issue['fields']['status']['name']

  #Getting the version of the products which had the bug

  #In some issues the version is not given
  #So this condition checks absence or presence of information about versions
  if len(issue['fields']['versions'])==0:
    #If no version information present then version field is empty string
    version=''
  else:
    #If it has version, then it can be more than one

    #Creating a list for version names
    version_names=[]

    #Iterating through each version
    for v in issue['fields']['versions']:

      #Fetching it's name
      name=v['name']

      #We just need the numerical values so removing the non-numerical part
      #Final version string variable
      final_name=''

      #For each character we will only store the number and '.'(dot)
      for c in name:

        #Check if the character is number or dot('.')
        if c.isnumeric() or c=='.':
          #if yes add it to final string name
          final_name=final_name+c

      #Add final version name to version lists
      version_names.append(final_name)
    
    #Add all version names in one string
    version=' '.join(version_names)

  #Add each column information in our row list
  row.extend([key,priority,created,status,version])

  #Add the row information in final data
  data.append(row)

# %%
#The final data
#Note: The data starts from latest bugs
data
# Out:
# [['AIRFLOW-7121', 'Major', '2020-05-26T22:08:20.000+0000', 'Open', '1.10.10'],
#  ['AIRFLOW-7120',
#   'Blocker',
#   '2020-04-28T12:14:24.000+0000',
#   'Open',
#   '1.10.10'],
#  ['AIRFLOW-7119', 'Minor', '2020-04-02T07:03:01.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7118',
#   'Minor',
#   '2020-04-01T19:34:38.000+0000',
#   'Resolved',
#   '1.10.5 1.10.6 1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-7117',
#   'Minor',
#   '2020-04-01T18:42:15.000+0000',
#   'Resolved',
#   '1.10.5 1.10.6 1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-7116', 'Major', '2020-04-01T00:49:58.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7115',
#   'Minor',
#   '2020-03-30T14:33:51.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7114',
#   'Minor',
#   '2020-03-30T13:57:11.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7113',
#   'Major',
#   '2020-03-27T18:22:28.000+0000',
#   'Closed',
#   '1.10.10'],
#  ['AIRFLOW-7112',
#   'Trivial',
#   '2020-03-27T10:07:53.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7111',
#   'Major',
#   '2020-03-25T17:11:25.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7110', 'Major', '2020-03-25T15:47:08.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7109', 'Major', '2020-03-25T14:26:31.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-7108',
#   'Major',
#   '2020-03-25T01:28:29.000+0000',
#   'Open',
#   '2.0.0 1.10.10'],
#  ['AIRFLOW-7107', 'Major', '2020-03-24T20:51:08.000+0000', 'Open', '1.10.8'],
#  ['AIRFLOW-7106', 'Minor', '2020-03-24T09:29:31.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7105',
#   'Major',
#   '2020-03-22T03:20:04.000+0000',
#   'Resolved',
#   '2.0.0 1.10.10'],
#  ['AIRFLOW-7104',
#   'Major',
#   '2020-03-21T11:19:27.000+0000',
#   'Resolved',
#   '2.0.0 1.10.10'],
#  ['AIRFLOW-7103', 'Minor', '2020-03-21T03:27:54.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7102', 'Major', '2020-03-20T21:59:07.000+0000', 'Open', '1.10.10'],
#  ['AIRFLOW-7101', 'Trivial', '2020-03-20T21:03:09.000+0000', 'Open', '1.10.0'],
#  ['AIRFLOW-7100',
#   'Minor',
#   '2020-03-20T13:54:31.000+0000',
#   'Resolved',
#   '1.10.8'],
#  ['AIRFLOW-7099',
#   'Major',
#   '2020-03-20T11:58:15.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7098',
#   'Major',
#   '2020-03-20T09:17:02.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7097',
#   'Major',
#   '2020-03-20T06:50:56.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7096',
#   'Major',
#   '2020-03-20T06:05:58.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7095', 'Major', '2020-03-20T04:50:43.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-7094', 'Major', '2020-03-19T20:50:21.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7093',
#   'Minor',
#   '2020-03-19T16:23:02.000+0000',
#   'Closed',
#   '1.10.5 1.10.6 1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-7092', 'Major', '2020-03-19T15:16:32.000+0000', 'Open', '1.10.8'],
#  ['AIRFLOW-7091',
#   'Critical',
#   '2020-03-19T12:43:02.000+0000',
#   'Closed',
#   '1.10.9'],
#  ['AIRFLOW-7090', 'Major', '2020-03-19T02:54:52.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7089',
#   'Major',
#   '2020-03-19T02:48:58.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7088',
#   'Major',
#   '2020-03-19T00:58:13.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7087',
#   'Major',
#   '2020-03-19T00:19:05.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7086', 'Minor', '2020-03-18T23:21:56.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7085',
#   'Major',
#   '2020-03-18T21:19:23.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7084',
#   'Major',
#   '2020-03-18T17:03:38.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7083', 'Minor', '2020-03-18T14:59:04.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7082',
#   'Minor',
#   '2020-03-18T09:03:15.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7081',
#   'Major',
#   '2020-03-18T08:47:54.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7080',
#   'Minor',
#   '2020-03-18T08:04:40.000+0000',
#   'Resolved',
#   '2.0.0 1.10.10'],
#  ['AIRFLOW-7079',
#   'Minor',
#   '2020-03-17T15:49:13.000+0000',
#   'Resolved',
#   '1.10.10'],
#  ['AIRFLOW-7078', 'Major', '2020-03-17T15:43:30.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7077',
#   'Major',
#   '2020-03-17T12:20:01.000+0000',
#   'Open',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-7076',
#   'Major',
#   '2020-03-16T16:00:50.000+0000',
#   'Resolved',
#   '2.0.0 1.10.10'],
#  ['AIRFLOW-7075', 'Major', '2020-03-16T15:55:54.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-7074',
#   'Major',
#   '2020-03-16T14:34:23.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7073',
#   'Major',
#   '2020-03-16T13:54:45.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7072', 'Minor', '2020-03-16T13:24:53.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7071', 'Minor', '2020-03-16T13:23:25.000+0000', 'Open', '1.10.8'],
#  ['AIRFLOW-7070', 'Minor', '2020-03-16T13:05:27.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7069',
#   'Major',
#   '2020-03-16T08:47:52.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7068',
#   'Minor',
#   '2020-03-15T13:50:06.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7067',
#   'Major',
#   '2020-03-15T10:39:52.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7066', 'Major', '2020-03-15T08:56:07.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7065',
#   'Minor',
#   '2020-03-15T01:58:58.000+0000',
#   'In Progress',
#   '1.10.9'],
#  ['AIRFLOW-7064',
#   'Major',
#   '2020-03-14T14:56:45.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7063',
#   'Major',
#   '2020-03-14T11:01:14.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7062',
#   'Major',
#   '2020-03-14T07:44:19.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7061',
#   'Minor',
#   '2020-03-14T07:33:32.000+0000',
#   'Resolved',
#   '2.0.0 1.10.10'],
#  ['AIRFLOW-7060', 'Major', '2020-03-14T07:16:46.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-7059',
#   'Minor',
#   '2020-03-13T17:37:43.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7058',
#   'Major',
#   '2020-03-13T17:18:44.000+0000',
#   'Open',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7057', 'Minor', '2020-03-13T13:33:20.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7056',
#   'Major',
#   '2020-03-13T09:51:38.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7055',
#   'Major',
#   '2020-03-13T07:42:09.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7054',
#   'Major',
#   '2020-03-13T07:09:46.000+0000',
#   'Open',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7053', 'Major', '2020-03-13T03:27:59.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7052', 'Major', '2020-03-12T19:57:55.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7051',
#   'Major',
#   '2020-03-12T18:26:48.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7050', 'Minor', '2020-03-12T17:06:26.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-7049',
#   'Minor',
#   '2020-03-12T16:37:25.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7048',
#   'Major',
#   '2020-03-12T13:58:38.000+0000',
#   'Resolved',
#   '1.10.0'],
#  ['AIRFLOW-7047',
#   'Major',
#   '2020-03-12T13:14:18.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7046',
#   'Minor',
#   '2020-03-12T11:43:05.000+0000',
#   'In Progress',
#   '1.10.10'],
#  ['AIRFLOW-7045',
#   'Major',
#   '2020-03-12T11:13:14.000+0000',
#   'Resolved',
#   '1.10.10'],
#  ['AIRFLOW-7044',
#   'Minor',
#   '2020-03-12T09:59:59.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7043',
#   'Blocker',
#   '2020-03-12T03:20:37.000+0000',
#   'In Progress',
#   '1.10.9'],
#  ['AIRFLOW-7042', 'Major', '2020-03-11T10:01:26.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7041',
#   'Major',
#   '2020-03-11T09:16:26.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7040',
#   'Major',
#   '2020-03-11T09:10:27.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7039',
#   'Critical',
#   '2020-03-10T22:49:25.000+0000',
#   'Open',
#   '1.10.7'],
#  ['AIRFLOW-7038', 'Major', '2020-03-10T20:05:06.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7037',
#   'Minor',
#   '2020-03-10T18:27:04.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7036', 'Major', '2020-03-10T18:22:49.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7035', 'Minor', '2020-03-10T18:21:00.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7034', 'Minor', '2020-03-10T17:07:23.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-7033', 'Major', '2020-03-10T16:32:46.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7032',
#   'Minor',
#   '2020-03-10T15:24:43.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7031', 'Minor', '2020-03-10T15:18:28.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7030', 'Major', '2020-03-10T13:50:13.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-7029',
#   'Minor',
#   '2020-03-10T12:35:52.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7028',
#   'Minor',
#   '2020-03-10T12:34:21.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7027', 'Blocker', '2020-03-10T10:45:57.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7026',
#   'Major',
#   '2020-03-10T01:13:53.000+0000',
#   'In Progress',
#   '1.10.9'],
#  ['AIRFLOW-7025',
#   'Major',
#   '2020-03-10T01:09:24.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7024',
#   'Major',
#   '2020-03-10T01:04:37.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7023',
#   'Trivial',
#   '2020-03-10T01:01:56.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7022',
#   'Major',
#   '2020-03-09T23:12:21.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7021',
#   'Minor',
#   '2020-03-09T21:44:54.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7020',
#   'Critical',
#   '2020-03-09T18:43:46.000+0000',
#   'Open',
#   '1.10.6'],
#  ['AIRFLOW-7019', 'Minor', '2020-03-09T18:43:04.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7018',
#   'Major',
#   '2020-03-09T16:35:05.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7017',
#   'Trivial',
#   '2020-03-09T15:16:58.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7016',
#   'Major',
#   '2020-03-09T12:10:03.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7015',
#   'Major',
#   '2020-03-09T09:30:49.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7014', 'Major', '2020-03-09T08:45:06.000+0000', 'Open', '1.10.0'],
#  ['AIRFLOW-7013',
#   'Major',
#   '2020-03-08T14:15:14.000+0000',
#   'Open',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7012',
#   'Major',
#   '2020-03-08T07:08:06.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-7011',
#   'Major',
#   '2020-03-08T06:47:43.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7010',
#   'Major',
#   '2020-03-08T03:14:53.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7009',
#   'Major',
#   '2020-03-07T22:21:47.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7008', 'Minor', '2020-03-07T21:26:20.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7007', 'Major', '2020-03-07T21:19:05.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7006',
#   'Major',
#   '2020-03-07T16:22:28.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7005',
#   'Major',
#   '2020-03-07T16:13:20.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7004', 'Major', '2020-03-07T13:53:32.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-7003',
#   'Major',
#   '2020-03-07T13:38:16.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-7002',
#   'Major',
#   '2020-03-07T10:44:20.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7001',
#   'Major',
#   '2020-03-07T07:50:55.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-7000',
#   'Trivial',
#   '2020-03-07T02:26:25.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6999', 'Minor', '2020-03-07T01:28:31.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6998',
#   'Major',
#   '2020-03-06T19:40:11.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6997',
#   'Major',
#   '2020-03-06T18:19:16.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6996',
#   'Major',
#   '2020-03-06T15:44:24.000+0000',
#   'Open',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-6995', 'Major', '2020-03-06T15:15:37.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6994',
#   'Major',
#   '2020-03-06T15:01:50.000+0000',
#   'In Progress',
#   '1.10.8 1.10.9'],
#  ['AIRFLOW-6993', 'Major', '2020-03-06T12:54:09.000+0000', 'Open', '1.10.3'],
#  ['AIRFLOW-6992', 'Minor', '2020-03-06T08:59:00.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6991', 'Major', '2020-03-05T22:31:59.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6990',
#   'Major',
#   '2020-03-05T16:32:47.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6989',
#   'Major',
#   '2020-03-05T15:38:18.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6988', 'Minor', '2020-03-05T13:48:10.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6987',
#   'Minor',
#   '2020-03-05T10:12:48.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6986', 'Major', '2020-03-05T05:15:11.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6985', 'Major', '2020-03-04T17:18:10.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6984',
#   'Minor',
#   '2020-03-04T16:22:27.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6983', 'Trivial', '2020-03-04T12:39:43.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6982', 'Major', '2020-03-04T09:50:12.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6981',
#   'Major',
#   '2020-03-04T02:15:28.000+0000',
#   'In Progress',
#   '2.0.0'],
#  ['AIRFLOW-6980',
#   'Major',
#   '2020-03-03T17:55:45.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6979',
#   'Major',
#   '2020-03-03T15:53:14.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6978',
#   'Major',
#   '2020-03-03T14:41:00.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6977',
#   'Minor',
#   '2020-03-03T13:32:35.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6976', 'Major', '2020-03-03T07:57:15.000+0000', 'Closed', '1.10.9'],
#  ['AIRFLOW-6975',
#   'Minor',
#   '2020-03-03T05:40:22.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6974', 'Minor', '2020-03-03T02:41:03.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6973',
#   'Minor',
#   '2020-03-02T17:42:04.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6972',
#   'Major',
#   '2020-03-02T17:37:44.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6971',
#   'Major',
#   '2020-03-02T17:01:09.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6970',
#   'Minor',
#   '2020-03-02T15:56:03.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6969', 'Major', '2020-03-01T21:30:29.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6968', 'Minor', '2020-03-01T19:30:46.000+0000', 'Open', '1.10.2'],
#  ['AIRFLOW-6967',
#   'Major',
#   '2020-03-01T16:47:29.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6966',
#   'Major',
#   '2020-03-01T14:24:46.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6965', 'Major', '2020-03-01T10:35:17.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6964', 'Major', '2020-03-01T10:19:25.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6963', 'Major', '2020-03-01T10:08:44.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6962',
#   'Trivial',
#   '2020-03-01T08:51:09.000+0000',
#   'Resolved',
#   '2.0.0 1.10.10'],
#  ['AIRFLOW-6961',
#   'Major',
#   '2020-03-01T00:01:04.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6960',
#   'Blocker',
#   '2020-02-29T16:19:12.000+0000',
#   'Open',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-6959',
#   'Minor',
#   '2020-02-29T13:56:50.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6958',
#   'Minor',
#   '2020-02-29T13:01:25.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6957',
#   'Major',
#   '2020-02-28T13:01:01.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6956',
#   'Major',
#   '2020-02-28T11:33:02.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6955',
#   'Major',
#   '2020-02-28T10:45:06.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6954',
#   'Minor',
#   '2020-02-28T10:40:45.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6953',
#   'Major',
#   '2020-02-28T09:20:50.000+0000',
#   'Open',
#   '1.10.0 1.10.1 1.10.2 1.10.3 1.10.4 1.10.5 1.10.6 1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-6952',
#   'Major',
#   '2020-02-28T06:32:55.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6951', 'Minor', '2020-02-28T05:41:13.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6950',
#   'Minor',
#   '2020-02-28T02:04:12.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6949',
#   'Minor',
#   '2020-02-27T21:21:50.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6948',
#   'Minor',
#   '2020-02-27T15:34:11.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6947', 'Major', '2020-02-27T12:16:03.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6946',
#   'Major',
#   '2020-02-27T10:03:31.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6945', 'Major', '2020-02-27T09:55:03.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6944', 'Minor', '2020-02-27T08:05:38.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6943', 'Major', '2020-02-27T07:51:06.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6942', 'Major', '2020-02-27T06:20:22.000+0000', 'Closed', '1.10.9'],
#  ['AIRFLOW-6941',
#   'Major',
#   '2020-02-27T05:31:57.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6940',
#   'Major',
#   '2020-02-27T04:09:32.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6939',
#   'Major',
#   '2020-02-27T02:47:17.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6938',
#   'Major',
#   '2020-02-27T00:52:17.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6937', 'Major', '2020-02-27T00:29:26.000+0000', 'Closed', '1.10.9'],
#  ['AIRFLOW-6936',
#   'Major',
#   '2020-02-27T00:19:29.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6935', 'Major', '2020-02-26T23:33:25.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6934', 'Major', '2020-02-26T23:24:13.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6933', 'Major', '2020-02-26T21:02:42.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6932',
#   'Major',
#   '2020-02-26T20:09:35.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-6931',
#   'Major',
#   '2020-02-26T18:10:33.000+0000',
#   'Reopened',
#   '1.10.9'],
#  ['AIRFLOW-6930', 'Major', '2020-02-26T16:57:03.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6929', 'Major', '2020-02-26T15:48:04.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6928', 'Major', '2020-02-26T15:42:16.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6927', 'Major', '2020-02-26T15:41:09.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6926',
#   'Major',
#   '2020-02-26T15:40:13.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6925', 'Major', '2020-02-26T15:39:42.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6924',
#   'Major',
#   '2020-02-26T15:39:10.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6923', 'Major', '2020-02-26T14:55:22.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6922', 'Major', '2020-02-26T10:14:31.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6921',
#   'Major',
#   '2020-02-26T09:21:15.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6920', 'Major', '2020-02-25T23:15:21.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6919',
#   'Major',
#   '2020-02-25T23:09:55.000+0000',
#   'Open',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-6918',
#   'Trivial',
#   '2020-02-25T21:12:37.000+0000',
#   'In Progress',
#   '1.10.9'],
#  ['AIRFLOW-6917', 'Major', '2020-02-25T20:52:03.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6916', 'Major', '2020-02-25T20:49:14.000+0000', 'Closed', '2.0.0'],
#  ['AIRFLOW-6915',
#   'Major',
#   '2020-02-25T15:04:13.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6914',
#   'Major',
#   '2020-02-25T13:34:12.000+0000',
#   'Reopened',
#   '1.10.6 1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-6913',
#   'Minor',
#   '2020-02-25T11:30:38.000+0000',
#   'Resolved',
#   '1.10.2'],
#  ['AIRFLOW-6912', 'Major', '2020-02-25T07:11:54.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6911', 'Major', '2020-02-25T02:26:21.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6910',
#   'Major',
#   '2020-02-25T00:58:05.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6909',
#   'Major',
#   '2020-02-25T00:27:32.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6908', 'Major', '2020-02-25T00:13:26.000+0000', 'Closed', '1.10.9'],
#  ['AIRFLOW-6907',
#   'Major',
#   '2020-02-24T22:39:21.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6906',
#   'Major',
#   '2020-02-24T20:34:49.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6905',
#   'Major',
#   '2020-02-24T17:03:09.000+0000',
#   'Resolved',
#   '1.10.10'],
#  ['AIRFLOW-6904',
#   'Critical',
#   '2020-02-24T14:42:08.000+0000',
#   'Resolved',
#   '1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-6903', 'Minor', '2020-02-24T09:44:48.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6902', 'Minor', '2020-02-24T09:44:20.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6901', 'Minor', '2020-02-24T09:44:04.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6900', 'Minor', '2020-02-24T09:43:46.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6899', 'Minor', '2020-02-24T09:42:43.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6898', 'Minor', '2020-02-24T09:41:28.000+0000', 'Open', '1.10.8'],
#  ['AIRFLOW-6897',
#   'Major',
#   '2020-02-24T03:36:40.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6896',
#   'Major',
#   '2020-02-24T01:22:34.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6895',
#   'Major',
#   '2020-02-24T01:00:17.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6894',
#   'Major',
#   '2020-02-23T21:25:17.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6893',
#   'Minor',
#   '2020-02-23T15:31:11.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6892',
#   'Major',
#   '2020-02-23T14:36:45.000+0000',
#   'Resolved',
#   '1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-6891', 'Major', '2020-02-23T13:03:57.000+0000', 'Closed', '1.10.9'],
#  ['AIRFLOW-6890',
#   'Major',
#   '2020-02-23T12:39:15.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6889',
#   'Minor',
#   '2020-02-23T11:39:50.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6888',
#   'Minor',
#   '2020-02-23T11:09:48.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6887',
#   'Major',
#   '2020-02-23T06:22:06.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6886', 'Major', '2020-02-22T19:18:00.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6885',
#   'Minor',
#   '2020-02-22T18:28:00.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6884',
#   'Major',
#   '2020-02-22T16:42:11.000+0000',
#   'Resolved',
#   '2.0.0 1.10.10'],
#  ['AIRFLOW-6883', 'Major', '2020-02-22T16:16:07.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6882', 'Major', '2020-02-22T15:40:05.000+0000', 'Open', '1.10.10'],
#  ['AIRFLOW-6881',
#   'Major',
#   '2020-02-22T14:53:10.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6880',
#   'Major',
#   '2020-02-22T13:42:33.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6879',
#   'Major',
#   '2020-02-22T10:16:26.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6878',
#   'Minor',
#   '2020-02-22T10:02:41.000+0000',
#   'Resolved',
#   '1.10.5 1.10.6 1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-6877',
#   'Major',
#   '2020-02-22T09:44:31.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6876', 'Major', '2020-02-22T04:19:53.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6875',
#   'Minor',
#   '2020-02-22T02:10:38.000+0000',
#   'Open',
#   '1.10.8 1.10.9'],
#  ['AIRFLOW-6874', 'Major', '2020-02-22T01:04:42.000+0000', 'Open', '1.10.4'],
#  ['AIRFLOW-6873',
#   'Trivial',
#   '2020-02-21T23:52:18.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6872',
#   'Major',
#   '2020-02-21T22:52:39.000+0000',
#   'Resolved',
#   '1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-6871',
#   'Major',
#   '2020-02-21T21:10:44.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6870', 'Major', '2020-02-21T19:17:10.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6869',
#   'Major',
#   '2020-02-21T16:47:41.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6868', 'Major', '2020-02-21T16:19:38.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6867',
#   'Major',
#   '2020-02-21T16:19:17.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6866',
#   'Major',
#   '2020-02-21T14:03:22.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-6865', 'Major', '2020-02-21T10:34:41.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6864',
#   'Major',
#   '2020-02-21T10:14:04.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6863',
#   'Major',
#   '2020-02-21T08:44:23.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6862',
#   'Major',
#   '2020-02-21T08:16:43.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6861',
#   'Major',
#   '2020-02-21T07:57:16.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6860',
#   'Minor',
#   '2020-02-21T05:51:20.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6859', 'Minor', '2020-02-21T02:07:53.000+0000', 'Closed', '1.10.9'],
#  ['AIRFLOW-6858',
#   'Major',
#   '2020-02-21T00:32:37.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6857',
#   'Major',
#   '2020-02-20T23:41:53.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6856',
#   'Major',
#   '2020-02-20T21:10:33.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6855',
#   'Minor',
#   '2020-02-20T19:17:46.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6854',
#   'Major',
#   '2020-02-20T16:01:44.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6853', 'Major', '2020-02-20T15:31:11.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6852', 'Major', '2020-02-20T14:58:07.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6851', 'Minor', '2020-02-20T10:00:52.000+0000', 'Closed', '1.10.9'],
#  ['AIRFLOW-6850',
#   'Major',
#   '2020-02-20T09:36:10.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6849', 'Minor', '2020-02-20T09:27:03.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6848',
#   'Major',
#   '2020-02-20T05:23:53.000+0000',
#   'Closed',
#   '1.10.5 1.10.8'],
#  ['AIRFLOW-6847', 'Minor', '2020-02-19T21:13:28.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6846', 'Minor', '2020-02-19T20:27:27.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6845', 'Major', '2020-02-19T20:00:26.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6844', 'Major', '2020-02-19T19:57:03.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6843',
#   'Major',
#   '2020-02-19T18:06:28.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6842',
#   'Major',
#   '2020-02-19T16:04:40.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6841',
#   'Major',
#   '2020-02-19T10:27:15.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-6840',
#   'Major',
#   '2020-02-19T08:06:13.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6839',
#   'Major',
#   '2020-02-19T02:18:27.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-6838',
#   'Major',
#   '2020-02-18T23:03:42.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-6837',
#   'Major',
#   '2020-02-18T22:51:04.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6836',
#   'Minor',
#   '2020-02-18T22:10:37.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6835', 'Major', '2020-02-18T20:57:24.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6834', 'Major', '2020-02-18T14:20:01.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6833',
#   'Minor',
#   '2020-02-18T13:18:41.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6832', 'Major', '2020-02-18T11:56:58.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6831', 'Major', '2020-02-18T09:26:30.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6830',
#   'Minor',
#   '2020-02-18T04:05:18.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6829',
#   'Major',
#   '2020-02-18T02:34:15.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6828',
#   'Major',
#   '2020-02-18T00:51:15.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6827', 'Major', '2020-02-17T23:51:24.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6826', 'Major', '2020-02-17T16:30:41.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6825',
#   'Blocker',
#   '2020-02-17T12:52:28.000+0000',
#   'Closed',
#   '1.10.7'],
#  ['AIRFLOW-6824',
#   'Minor',
#   '2020-02-17T11:30:40.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6823',
#   'Minor',
#   '2020-02-17T11:24:06.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6822',
#   'Minor',
#   '2020-02-17T09:42:45.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6821',
#   'Minor',
#   '2020-02-17T01:42:46.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6820',
#   'Major',
#   '2020-02-16T13:11:10.000+0000',
#   'Resolved',
#   '1.10.10'],
#  ['AIRFLOW-6819', 'Major', '2020-02-16T12:48:03.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6818',
#   'Minor',
#   '2020-02-16T11:51:15.000+0000',
#   'Resolved',
#   '1.10.10'],
#  ['AIRFLOW-6817',
#   'Major',
#   '2020-02-16T09:07:19.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6816',
#   'Major',
#   '2020-02-16T07:30:18.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-6815',
#   'Blocker',
#   '2020-02-15T10:53:42.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6814',
#   'Blocker',
#   '2020-02-15T02:42:02.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6813', 'Blocker', '2020-02-14T23:55:00.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6812',
#   'Minor',
#   '2020-02-14T21:07:27.000+0000',
#   'Open',
#   '1.10.3 2.0.0 1.10.9'],
#  ['AIRFLOW-6811', 'Major', '2020-02-14T18:18:45.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6810', 'Major', '2020-02-14T16:18:24.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6809',
#   'Major',
#   '2020-02-14T13:10:39.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6808', 'Minor', '2020-02-14T11:36:55.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6807', 'Major', '2020-02-14T09:55:34.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6806',
#   'Blocker',
#   '2020-02-14T09:19:15.000+0000',
#   'Closed',
#   '1.10.9'],
#  ['AIRFLOW-6805', 'Major', '2020-02-14T08:37:07.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6804',
#   'Major',
#   '2020-02-14T07:56:07.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6803',
#   'Trivial',
#   '2020-02-14T06:13:30.000+0000',
#   'Closed',
#   '2.0.0'],
#  ['AIRFLOW-6802',
#   'Critical',
#   '2020-02-14T05:02:16.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6801',
#   'Trivial',
#   '2020-02-14T01:03:34.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6800',
#   'Trivial',
#   '2020-02-14T01:03:10.000+0000',
#   'Closed',
#   '1.10.9'],
#  ['AIRFLOW-6799',
#   'Blocker',
#   '2020-02-13T22:30:49.000+0000',
#   'Closed',
#   '1.10.7 1.10.9'],
#  ['AIRFLOW-6798', 'Major', '2020-02-13T20:58:48.000+0000', 'Closed', '1.10.3'],
#  ['AIRFLOW-6797', 'Minor', '2020-02-13T20:52:15.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6796',
#   'Major',
#   '2020-02-13T19:43:52.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6795',
#   'Major',
#   '2020-02-13T18:30:55.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6794', 'Trivial', '2020-02-13T14:59:16.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6793',
#   'Major',
#   '2020-02-13T14:28:32.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6792',
#   'Major',
#   '2020-02-13T13:18:15.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6791', 'Major', '2020-02-13T11:03:48.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6790',
#   'Major',
#   '2020-02-13T10:32:46.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-6789',
#   'Major',
#   '2020-02-13T09:01:32.000+0000',
#   'Resolved',
#   '1.10.8 1.10.9'],
#  ['AIRFLOW-6788', 'Major', '2020-02-12T22:25:14.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6787',
#   'Minor',
#   '2020-02-12T20:46:14.000+0000',
#   'Open',
#   '1.10.8 1.10.9'],
#  ['AIRFLOW-6786',
#   'Minor',
#   '2020-02-12T20:28:02.000+0000',
#   'In Progress',
#   '1.10.9'],
#  ['AIRFLOW-6785',
#   'Major',
#   '2020-02-12T18:13:25.000+0000',
#   'Open',
#   '1.10.4 1.10.5 1.10.6 1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-6784',
#   'Major',
#   '2020-02-12T16:36:52.000+0000',
#   'Closed',
#   '1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-6783', 'Minor', '2020-02-12T15:49:13.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6782', 'Major', '2020-02-12T15:12:28.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6781',
#   'Major',
#   '2020-02-12T04:16:28.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6780',
#   'Blocker',
#   '2020-02-12T03:20:15.000+0000',
#   'Open',
#   '1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-6779', 'Critical', '2020-02-12T01:33:25.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6778',
#   'Blocker',
#   '2020-02-11T22:22:47.000+0000',
#   'Open',
#   '1.10.6 1.10.7 1.10.8 1.10.9'],
#  ['AIRFLOW-6777', 'Minor', '2020-02-11T22:05:03.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6776',
#   'Major',
#   '2020-02-11T18:46:27.000+0000',
#   'Open',
#   '1.10.7 1.10.9'],
#  ['AIRFLOW-6775', 'Major', '2020-02-11T15:47:40.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6774', 'Minor', '2020-02-11T13:53:08.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6773', 'Minor', '2020-02-11T13:45:49.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6772',
#   'Critical',
#   '2020-02-11T12:30:06.000+0000',
#   'Open',
#   '1.10.7'],
#  ['AIRFLOW-6771', 'Major', '2020-02-11T06:29:06.000+0000', 'Closed', '1.9.0'],
#  ['AIRFLOW-6770',
#   'Minor',
#   '2020-02-11T03:31:03.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6769', 'Major', '2020-02-10T18:35:18.000+0000', 'Open', '1.10.9'],
#  ['AIRFLOW-6768',
#   'Minor',
#   '2020-02-10T14:54:16.000+0000',
#   'Open',
#   '1.10.8 1.10.9'],
#  ['AIRFLOW-6767',
#   'Minor',
#   '2020-02-10T14:26:03.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6766',
#   'Major',
#   '2020-02-10T11:31:39.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6765',
#   'Major',
#   '2020-02-10T07:25:35.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6764',
#   'Major',
#   '2020-02-09T17:21:58.000+0000',
#   'Resolved',
#   '2.0.0 1.10.9'],
#  ['AIRFLOW-6763',
#   'Major',
#   '2020-02-09T15:33:00.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6762',
#   'Major',
#   '2020-02-09T13:17:12.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6761',
#   'Major',
#   '2020-02-09T12:28:36.000+0000',
#   'Resolved',
#   '1.10.8 1.10.9'],
#  ['AIRFLOW-6760',
#   'Major',
#   '2020-02-09T06:46:51.000+0000',
#   'Open',
#   '1.10.8 1.10.9'],
#  ['AIRFLOW-6759',
#   'Minor',
#   '2020-02-08T18:50:46.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6758',
#   'Major',
#   '2020-02-07T14:51:14.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6757', 'Major', '2020-02-07T14:45:41.000+0000', 'Closed', '2.0.0'],
#  ['AIRFLOW-6756',
#   'Major',
#   '2020-02-07T13:42:32.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6755',
#   'Major',
#   '2020-02-07T13:15:25.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6754', 'Major', '2020-02-07T12:43:48.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6753',
#   'Major',
#   '2020-02-07T11:22:30.000+0000',
#   'Resolved',
#   '1.10.10'],
#  ['AIRFLOW-6752',
#   'Minor',
#   '2020-02-07T09:54:06.000+0000',
#   'Resolved',
#   '1.10.8'],
#  ['AIRFLOW-6751',
#   'Major',
#   '2020-02-07T09:20:28.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6750',
#   'Blocker',
#   '2020-02-06T22:33:01.000+0000',
#   'Resolved',
#   '1.10.6 1.10.7'],
#  ['AIRFLOW-6749', 'Minor', '2020-02-06T19:57:43.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6748', 'Major', '2020-02-06T19:19:53.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6747', 'Minor', '2020-02-06T09:32:07.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6746',
#   'Major',
#   '2020-02-06T09:20:30.000+0000',
#   'Resolved',
#   '1.10.5'],
#  ['AIRFLOW-6745', 'Major', '2020-02-06T09:14:33.000+0000', 'Closed', '1.10.5'],
#  ['AIRFLOW-6744', 'Trivial', '2020-02-06T03:59:58.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6743', 'Trivial', '2020-02-06T03:56:24.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6742',
#   'Major',
#   '2020-02-06T01:37:52.000+0000',
#   'Closed',
#   '1.10.7 1.10.8'],
#  ['AIRFLOW-6741', 'Major', '2020-02-05T20:15:03.000+0000', 'Open', '1.10.1'],
#  ['AIRFLOW-6740',
#   'Minor',
#   '2020-02-05T20:09:17.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6739',
#   'Trivial',
#   '2020-02-05T15:44:51.000+0000',
#   'Resolved',
#   '1.10.10'],
#  ['AIRFLOW-6738',
#   'Major',
#   '2020-02-05T15:24:30.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6737',
#   'Major',
#   '2020-02-05T15:21:23.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6736',
#   'Major',
#   '2020-02-05T15:07:04.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6735', 'Minor', '2020-02-05T13:26:59.000+0000', 'Open', '1.10.8'],
#  ['AIRFLOW-6734',
#   'Minor',
#   '2020-02-05T13:16:24.000+0000',
#   'Resolved',
#   '1.10.8'],
#  ['AIRFLOW-6733',
#   'Minor',
#   '2020-02-05T12:10:29.000+0000',
#   'Resolved',
#   '1.10.8'],
#  ['AIRFLOW-6732',
#   'Minor',
#   '2020-02-05T11:34:41.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6731',
#   'Major',
#   '2020-02-05T10:34:41.000+0000',
#   'Open',
#   '1.10.5 1.10.6 1.10.7'],
#  ['AIRFLOW-6730',
#   'Major',
#   '2020-02-04T23:49:14.000+0000',
#   'Resolved',
#   '1.10.4'],
#  ['AIRFLOW-6729', 'Minor', '2020-02-04T09:43:03.000+0000', 'Open', '1.10.2'],
#  ['AIRFLOW-6728',
#   'Major',
#   '2020-02-04T00:30:52.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6727',
#   'Minor',
#   '2020-02-03T22:21:17.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6726',
#   'Minor',
#   '2020-02-03T16:00:51.000+0000',
#   'Open',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6725',
#   'Minor',
#   '2020-02-03T14:35:48.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6724',
#   'Minor',
#   '2020-02-03T07:52:10.000+0000',
#   'Resolved',
#   '1.10.8'],
#  ['AIRFLOW-6723',
#   'Major',
#   '2020-02-02T23:00:13.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6722',
#   'Minor',
#   '2020-02-02T22:44:19.000+0000',
#   'Open',
#   '1.10.6 1.10.7'],
#  ['AIRFLOW-6721',
#   'Major',
#   '2020-02-02T22:12:01.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6720',
#   'Major',
#   '2020-02-02T21:57:33.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6719', 'Major', '2020-02-02T21:35:46.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6718',
#   'Minor',
#   '2020-02-02T21:21:22.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6717',
#   'Minor',
#   '2020-02-02T21:11:35.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6716',
#   'Minor',
#   '2020-02-02T21:05:15.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6715',
#   'Minor',
#   '2020-02-02T20:21:26.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6714',
#   'Minor',
#   '2020-02-02T20:20:32.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6713',
#   'Major',
#   '2020-02-02T15:32:38.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6712', 'Major', '2020-02-02T14:56:20.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6711',
#   'Major',
#   '2020-02-02T12:38:23.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6710',
#   'Major',
#   '2020-02-02T07:38:18.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6709',
#   'Major',
#   '2020-02-02T07:10:38.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6708',
#   'Major',
#   '2020-02-01T22:04:58.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6707',
#   'Major',
#   '2020-02-01T21:13:55.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6706',
#   'Major',
#   '2020-02-01T16:53:28.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6705',
#   'Major',
#   '2020-02-01T15:47:25.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6704',
#   'Major',
#   '2020-02-01T14:51:23.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6703',
#   'Major',
#   '2020-02-01T13:29:35.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6702',
#   'Major',
#   '2020-02-01T13:19:47.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6701',
#   'Major',
#   '2020-02-01T11:56:42.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6700',
#   'Major',
#   '2020-02-01T07:49:43.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6699',
#   'Minor',
#   '2020-01-31T20:43:11.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6698',
#   'Major',
#   '2020-01-31T19:49:51.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6697',
#   'Minor',
#   '2020-01-31T18:47:42.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6696',
#   'Critical',
#   '2020-01-31T17:16:14.000+0000',
#   'Closed',
#   '1.10.7'],
#  ['AIRFLOW-6695',
#   'Minor',
#   '2020-01-31T16:51:06.000+0000',
#   'Resolved',
#   '1.10.10'],
#  ['AIRFLOW-6694',
#   'Major',
#   '2020-01-31T14:59:26.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6693',
#   'Minor',
#   '2020-01-31T14:19:52.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6692',
#   'Major',
#   '2020-01-31T08:57:26.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6691',
#   'Major',
#   '2020-01-30T23:54:19.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6690', 'Major', '2020-01-30T23:53:39.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6689',
#   'Major',
#   '2020-01-30T23:19:16.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6688', 'Major', '2020-01-30T23:11:49.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6687', 'Major', '2020-01-30T22:12:01.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6686',
#   'Major',
#   '2020-01-30T20:14:07.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6685',
#   'Major',
#   '2020-01-30T19:45:15.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6684', 'Major', '2020-01-30T18:45:34.000+0000', 'Open', '1.10.5'],
#  ['AIRFLOW-6683',
#   'Major',
#   '2020-01-30T12:45:03.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6682',
#   'Major',
#   '2020-01-30T00:54:22.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6681', 'Major', '2020-01-29T23:29:53.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6680', 'Major', '2020-01-29T20:57:36.000+0000', 'Open', '1.10.8'],
#  ['AIRFLOW-6679',
#   'Minor',
#   '2020-01-29T20:22:58.000+0000',
#   'Open',
#   '2.0.0 1.10.10'],
#  ['AIRFLOW-6678',
#   'Minor',
#   '2020-01-29T16:08:26.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6677',
#   'Major',
#   '2020-01-29T13:30:10.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6676',
#   'Minor',
#   '2020-01-29T12:57:18.000+0000',
#   'Resolved',
#   '1.10.8'],
#  ['AIRFLOW-6675', 'Minor', '2020-01-29T11:04:13.000+0000', 'Open', '1.10.5'],
#  ['AIRFLOW-6674',
#   'Major',
#   '2020-01-29T09:40:36.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6673', 'Minor', '2020-01-29T08:21:32.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6672',
#   'Minor',
#   '2020-01-29T05:18:24.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6671', 'Major', '2020-01-29T02:10:40.000+0000', 'Open', '1.10.2'],
#  ['AIRFLOW-6670',
#   'Major',
#   '2020-01-28T21:59:02.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6669',
#   'Major',
#   '2020-01-28T21:49:40.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6668', 'Major', '2020-01-28T20:51:20.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6667',
#   'Major',
#   '2020-01-28T20:09:06.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6666',
#   'Major',
#   '2020-01-28T20:07:35.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6665', 'Major', '2020-01-28T19:54:33.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6664', 'Major', '2020-01-28T16:20:19.000+0000', 'Closed', '2.0.0'],
#  ['AIRFLOW-6663',
#   'Major',
#   '2020-01-28T16:19:37.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6662',
#   'Major',
#   '2020-01-28T15:15:36.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6661',
#   'Major',
#   '2020-01-28T14:59:44.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6660',
#   'Major',
#   '2020-01-28T13:55:10.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6659',
#   'Minor',
#   '2020-01-28T13:01:21.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6658',
#   'Major',
#   '2020-01-28T08:34:08.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6657', 'Major', '2020-01-28T08:28:07.000+0000', 'Open', '1.10.4'],
#  ['AIRFLOW-6656',
#   'Major',
#   '2020-01-28T08:22:46.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6655',
#   'Major',
#   '2020-01-28T08:17:58.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6654',
#   'Minor',
#   '2020-01-28T07:58:21.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6653', 'Major', '2020-01-28T05:47:07.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6652', 'Major', '2020-01-28T04:54:56.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6651', 'Major', '2020-01-27T19:37:17.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6650',
#   'Minor',
#   '2020-01-27T15:32:27.000+0000',
#   'Resolved',
#   '1.10.4 1.10.5 1.10.6 1.10.7'],
#  ['AIRFLOW-6649', 'Major', '2020-01-27T13:13:22.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6648',
#   'Minor',
#   '2020-01-27T11:52:15.000+0000',
#   'In Progress',
#   '1.10.0'],
#  ['AIRFLOW-6647', 'Minor', '2020-01-27T11:11:53.000+0000', 'Open', '1.10.0'],
#  ['AIRFLOW-6646',
#   'Major',
#   '2020-01-27T10:14:48.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6645', 'Major', '2020-01-27T04:03:06.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6644',
#   'Major',
#   '2020-01-26T23:05:49.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6643',
#   'Major',
#   '2020-01-25T22:53:58.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6642',
#   'Major',
#   '2020-01-25T22:32:54.000+0000',
#   'Open',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6641',
#   'Major',
#   '2020-01-25T21:54:52.000+0000',
#   'Open',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6640',
#   'Major',
#   '2020-01-25T21:33:33.000+0000',
#   'Open',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6639',
#   'Minor',
#   '2020-01-25T14:07:28.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6638',
#   'Major',
#   '2020-01-25T13:37:44.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6637', 'Major', '2020-01-25T12:02:54.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6636',
#   'Major',
#   '2020-01-25T11:47:51.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6635',
#   'Major',
#   '2020-01-25T10:58:32.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6634',
#   'Major',
#   '2020-01-25T08:15:13.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6633', 'Major', '2020-01-24T20:20:55.000+0000', 'Closed', '1.10.7'],
#  ['AIRFLOW-6632',
#   'Major',
#   '2020-01-24T19:29:43.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6631', 'Major', '2020-01-24T19:18:12.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6630',
#   'Major',
#   '2020-01-24T19:11:12.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6629', 'Major', '2020-01-24T17:17:45.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6628',
#   'Minor',
#   '2020-01-24T16:01:49.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7 1.10.10'],
#  ['AIRFLOW-6627',
#   'Minor',
#   '2020-01-24T14:03:52.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6626',
#   'Major',
#   '2020-01-24T02:12:40.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6625',
#   'Minor',
#   '2020-01-23T21:18:41.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6624',
#   'Major',
#   '2020-01-23T18:24:12.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6623', 'Major', '2020-01-23T14:09:34.000+0000', 'Open', '1.10.1'],
#  ['AIRFLOW-6622', 'Major', '2020-01-23T13:59:58.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6621', 'Major', '2020-01-23T13:43:45.000+0000', 'Closed', '1.10.7'],
#  ['AIRFLOW-6620',
#   'Major',
#   '2020-01-23T12:17:14.000+0000',
#   'Resolved',
#   '1.10.8'],
#  ['AIRFLOW-6619',
#   'Major',
#   '2020-01-23T08:02:12.000+0000',
#   'Resolved',
#   '1.10.10'],
#  ['AIRFLOW-6618', 'Major', '2020-01-22T15:15:40.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6617',
#   'Minor',
#   '2020-01-22T13:01:52.000+0000',
#   'Resolved',
#   '1.10.8'],
#  ['AIRFLOW-6616',
#   'Minor',
#   '2020-01-22T10:53:01.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6615',
#   'Major',
#   '2020-01-22T07:29:54.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6614',
#   'Major',
#   '2020-01-22T06:47:23.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6613',
#   'Major',
#   '2020-01-22T00:52:35.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6612', 'Minor', '2020-01-21T22:54:34.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6611',
#   'Minor',
#   '2020-01-21T20:58:53.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6610',
#   'Major',
#   '2020-01-21T14:45:29.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6609', 'Major', '2020-01-21T12:46:09.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6608',
#   'Minor',
#   '2020-01-21T11:47:36.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6607',
#   'Major',
#   '2020-01-21T09:56:52.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6606', 'Minor', '2020-01-20T23:49:00.000+0000', 'Closed', '1.10.7'],
#  ['AIRFLOW-6605', 'Trivial', '2020-01-20T21:09:06.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6604', 'Major', '2020-01-20T15:49:50.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6603',
#   'Major',
#   '2020-01-20T15:35:03.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6602',
#   'Major',
#   '2020-01-20T10:44:12.000+0000',
#   'In Progress',
#   '1.10.7'],
#  ['AIRFLOW-6601', 'Major', '2020-01-20T05:17:22.000+0000', 'Open', '1.10.10'],
#  ['AIRFLOW-6600', 'Major', '2020-01-20T04:53:07.000+0000', 'Open', '1.10.10'],
#  ['AIRFLOW-6599', 'Major', '2020-01-20T04:44:04.000+0000', 'Open', '1.10.10'],
#  ['AIRFLOW-6598', 'Major', '2020-01-20T04:36:04.000+0000', 'Open', '1.10.10'],
#  ['AIRFLOW-6597',
#   'Major',
#   '2020-01-20T00:21:40.000+0000',
#   'Resolved',
#   '1.10.10'],
#  ['AIRFLOW-6596',
#   'Minor',
#   '2020-01-19T10:28:15.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6595',
#   'Minor',
#   '2020-01-19T10:00:44.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6594',
#   'Major',
#   '2020-01-19T04:44:38.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6593',
#   'Minor',
#   '2020-01-19T02:50:29.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6592',
#   'Major',
#   '2020-01-18T20:11:20.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6591',
#   'Major',
#   '2020-01-18T15:00:54.000+0000',
#   'Resolved',
#   '1.10.8'],
#  ['AIRFLOW-6590',
#   'Minor',
#   '2020-01-18T13:33:27.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6589',
#   'Major',
#   '2020-01-18T11:54:18.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6588',
#   'Minor',
#   '2020-01-18T06:00:11.000+0000',
#   'Resolved',
#   '1.10.9'],
#  ['AIRFLOW-6587', 'Trivial', '2020-01-17T22:44:09.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6586', 'Minor', '2020-01-17T22:10:39.000+0000', 'Open', '1.10.3'],
#  ['AIRFLOW-6585',
#   'Major',
#   '2020-01-17T08:04:31.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6584',
#   'Major',
#   '2020-01-17T07:39:20.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6583',
#   'Minor',
#   '2020-01-17T02:33:01.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6582', 'Minor', '2020-01-16T18:09:00.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6581', 'Major', '2020-01-16T12:16:19.000+0000', 'Open', '1.10.2'],
#  ['AIRFLOW-6580', 'Blocker', '2020-01-16T12:12:10.000+0000', 'Open', '1.10.2'],
#  ['AIRFLOW-6579', 'Major', '2020-01-16T09:28:35.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6578',
#   'Major',
#   '2020-01-16T08:58:32.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6577', 'Minor', '2020-01-16T01:51:13.000+0000', 'Closed', '1.10.7'],
#  ['AIRFLOW-6576',
#   'Major',
#   '2020-01-16T00:29:19.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6575',
#   'Major',
#   '2020-01-15T22:57:37.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6574', 'Major', '2020-01-15T21:56:11.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6573',
#   'Trivial',
#   '2020-01-15T16:49:02.000+0000',
#   'Resolved',
#   '1.10.10'],
#  ['AIRFLOW-6572',
#   'Major',
#   '2020-01-15T15:38:08.000+0000',
#   'Resolved',
#   '1.10.7'],
# ...
#  ['AIRFLOW-6306', 'Minor', '2019-12-19T11:09:56.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6305', 'Minor', '2019-12-19T11:09:35.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6304', 'Minor', '2019-12-19T11:09:02.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6303', 'Minor', '2019-12-19T11:08:43.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6302', 'Minor', '2019-12-19T11:08:13.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6301', 'Minor', '2019-12-19T11:07:36.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6300', 'Minor', '2019-12-19T11:06:42.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6299', 'Minor', '2019-12-19T11:06:14.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6298', 'Minor', '2019-12-19T11:05:33.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6297',
#   'Major',
#   '2019-12-19T07:38:19.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6296',
#   'Major',
#   '2019-12-19T05:54:06.000+0000',
#   'Resolved',
#   '1.10.7'],
#  ['AIRFLOW-6295', 'Minor', '2019-12-18T22:34:25.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6294',
#   'Minor',
#   '2019-12-18T22:33:55.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6293',
#   'Minor',
#   '2019-12-18T22:33:05.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6292',
#   'Minor',
#   '2019-12-18T22:32:32.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6291',
#   'Minor',
#   '2019-12-18T22:31:35.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6290',
#   'Minor',
#   '2019-12-18T22:31:11.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6289',
#   'Minor',
#   '2019-12-18T22:30:33.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6288',
#   'Minor',
#   '2019-12-18T22:29:58.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6287', 'Minor', '2019-12-18T22:29:17.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6286', 'Minor', '2019-12-18T22:28:48.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6285', 'Minor', '2019-12-18T22:28:16.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6284', 'Minor', '2019-12-18T22:27:29.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6283', 'Minor', '2019-12-18T22:26:29.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6282', 'Minor', '2019-12-18T22:25:48.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6281', 'Minor', '2019-12-18T22:25:28.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6280', 'Minor', '2019-12-18T22:25:00.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6279', 'Minor', '2019-12-18T22:24:34.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6278', 'Minor', '2019-12-18T22:24:15.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6277', 'Minor', '2019-12-18T22:23:37.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6276', 'Minor', '2019-12-18T22:23:03.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6275', 'Minor', '2019-12-18T22:21:22.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6274',
#   'Major',
#   '2019-12-18T22:01:10.000+0000',
#   'Closed',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6273', 'Major', '2019-12-18T21:17:09.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6272',
#   'Minor',
#   '2019-12-18T20:43:36.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6271',
#   'Major',
#   '2019-12-18T17:44:47.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6270',
#   'Major',
#   '2019-12-18T17:41:50.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6269',
#   'Minor',
#   '2019-12-18T17:01:45.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6268',
#   'Minor',
#   '2019-12-18T10:42:40.000+0000',
#   'Resolved',
#   '2.0.0 1.10.6'],
#  ['AIRFLOW-6267',
#   'Major',
#   '2019-12-18T02:33:58.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6266', 'Major', '2019-12-17T19:21:11.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6265',
#   'Minor',
#   '2019-12-17T19:04:57.000+0000',
#   'Open',
#   '1.10.2 1.10.3 1.10.4 2.0.0 1.10.5 1.10.6'],
#  ['AIRFLOW-6264', 'Major', '2019-12-17T17:53:15.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6263',
#   'Major',
#   '2019-12-16T22:23:33.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6262', 'Minor', '2019-12-16T21:47:37.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6261',
#   'Trivial',
#   '2019-12-16T16:03:33.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6260',
#   'Minor',
#   '2019-12-16T15:56:52.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6259',
#   'Minor',
#   '2019-12-16T15:39:16.000+0000',
#   'Resolved',
#   '2.0.0 1.10.6'],
#  ['AIRFLOW-6258',
#   'Major',
#   '2019-12-15T12:17:12.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6257', 'Major', '2019-12-14T11:00:10.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6256',
#   'Major',
#   '2019-12-14T08:34:09.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6255', 'Minor', '2019-12-14T07:45:24.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6254',
#   'Major',
#   '2019-12-14T06:25:17.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6253', 'Major', '2019-12-13T15:09:12.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6252', 'Minor', '2019-12-13T09:46:14.000+0000', 'Open', '1.10.3'],
#  ['AIRFLOW-6251',
#   'Major',
#   '2019-12-13T07:33:59.000+0000',
#   'In Progress',
#   '1.10.6'],
#  ['AIRFLOW-6250',
#   'Major',
#   '2019-12-13T07:30:45.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6249', 'Minor', '2019-12-13T06:25:46.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6248', 'Trivial', '2019-12-13T02:02:22.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6247',
#   'Minor',
#   '2019-12-13T00:16:44.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6246',
#   'Major',
#   '2019-12-13T00:02:46.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6245',
#   'Minor',
#   '2019-12-12T23:01:52.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6244', 'Major', '2019-12-12T21:30:42.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6243',
#   'Major',
#   '2019-12-12T21:08:43.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6242',
#   'Major',
#   '2019-12-12T18:00:14.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6241',
#   'Minor',
#   '2019-12-12T17:31:53.000+0000',
#   'Resolved',
#   '1.10.5 1.10.6'],
#  ['AIRFLOW-6240',
#   'Minor',
#   '2019-12-12T16:55:03.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6239',
#   'Minor',
#   '2019-12-12T16:20:23.000+0000',
#   'Resolved',
#   '2.0.0 1.10.6'],
#  ['AIRFLOW-6238',
#   'Minor',
#   '2019-12-12T15:34:37.000+0000',
#   'Resolved',
#   '2.0.0 1.10.6'],
#  ['AIRFLOW-6237', 'Minor', '2019-12-12T15:07:27.000+0000', 'Open', '1.10.4'],
#  ['AIRFLOW-6236',
#   'Major',
#   '2019-12-12T15:05:05.000+0000',
#   'Open',
#   '1.10.5 1.10.6'],
#  ['AIRFLOW-6235', 'Major', '2019-12-12T14:20:11.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6234',
#   'Minor',
#   '2019-12-12T14:13:23.000+0000',
#   'Open',
#   '2.0.0 1.10.6 1.10.7'],
#  ['AIRFLOW-6233', 'Blocker', '2019-12-12T08:23:06.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6232', 'Minor', '2019-12-12T08:15:24.000+0000', 'Closed', '1.6.2'],
#  ['AIRFLOW-6231',
#   'Trivial',
#   '2019-12-11T23:41:01.000+0000',
#   'In Progress',
#   '1.10.6'],
#  ['AIRFLOW-6230',
#   'Major',
#   '2019-12-11T11:08:42.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6229',
#   'Major',
#   '2019-12-11T10:31:45.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6228', 'Major', '2019-12-11T09:30:30.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6227', 'Major', '2019-12-11T09:28:59.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6226',
#   'Major',
#   '2019-12-10T22:59:59.000+0000',
#   'Resolved',
#   '2.0.0 1.10.6'],
#  ['AIRFLOW-6225', 'Minor', '2019-12-10T21:58:04.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6224', 'Major', '2019-12-10T20:09:04.000+0000', 'Closed', '2.0.0'],
#  ['AIRFLOW-6223',
#   'Minor',
#   '2019-12-10T17:44:15.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6222',
#   'Trivial',
#   '2019-12-10T17:38:39.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6221',
#   'Major',
#   '2019-12-10T17:25:55.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6220',
#   'Minor',
#   '2019-12-10T17:17:14.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6219', 'Major', '2019-12-10T16:39:11.000+0000', 'Open', '1.10.2'],
#  ['AIRFLOW-6218', 'Major', '2019-12-10T14:43:40.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6217', 'Major', '2019-12-10T13:19:29.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6216',
#   'Major',
#   '2019-12-10T10:44:52.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6215', 'Minor', '2019-12-10T09:37:27.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6214', 'Minor', '2019-12-10T09:08:50.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6213', 'Major', '2019-12-10T08:06:59.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6212', 'Trivial', '2019-12-10T07:58:24.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6211',
#   'Minor',
#   '2019-12-10T06:05:30.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6210', 'Major', '2019-12-10T04:09:23.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6209',
#   'Major',
#   '2019-12-10T02:26:34.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6208', 'Major', '2019-12-10T00:54:21.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6207',
#   'Critical',
#   '2019-12-09T20:34:25.000+0000',
#   'Open',
#   '1.10.6'],
#  ['AIRFLOW-6206',
#   'Major',
#   '2019-12-09T20:08:17.000+0000',
#   'In Progress',
#   '1.10.6'],
#  ['AIRFLOW-6205',
#   'Major',
#   '2019-12-09T20:02:07.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6204',
#   'Major',
#   '2019-12-09T11:05:51.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6203',
#   'Minor',
#   '2019-12-09T08:57:38.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6202', 'Major', '2019-12-09T03:09:41.000+0000', 'Closed', '1.9.0'],
#  ['AIRFLOW-6201',
#   'Major',
#   '2019-12-09T02:44:13.000+0000',
#   'Resolved',
#   '1.10.4'],
#  ['AIRFLOW-6200', 'Major', '2019-12-08T23:59:01.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6199',
#   'Major',
#   '2019-12-08T23:13:00.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6198', 'Major', '2019-12-08T22:32:12.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6197',
#   'Major',
#   '2019-12-08T19:00:55.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6196',
#   'Major',
#   '2019-12-08T15:53:29.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6195',
#   'Minor',
#   '2019-12-08T12:47:20.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6194', 'Major', '2019-12-07T21:52:39.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6193',
#   'Major',
#   '2019-12-07T19:48:20.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6192',
#   'Minor',
#   '2019-12-06T17:08:27.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6191',
#   'Major',
#   '2019-12-06T12:51:42.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6190', 'Minor', '2019-12-06T12:05:09.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6189',
#   'Major',
#   '2019-12-06T11:02:39.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6188',
#   'Major',
#   '2019-12-06T06:46:12.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6187',
#   'Minor',
#   '2019-12-05T23:43:17.000+0000',
#   'In Progress',
#   '1.10.6'],
#  ['AIRFLOW-6186',
#   'Major',
#   '2019-12-05T21:13:08.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6185',
#   'Minor',
#   '2019-12-05T20:48:56.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6184', 'Minor', '2019-12-05T18:49:19.000+0000', 'Open', '1.10.7'],
#  ['AIRFLOW-6183',
#   'Major',
#   '2019-12-05T17:16:41.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6182', 'Major', '2019-12-05T16:04:26.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6181',
#   'Major',
#   '2019-12-05T15:01:02.000+0000',
#   'Resolved',
#   '2.0.0 1.10.7'],
#  ['AIRFLOW-6180',
#   'Major',
#   '2019-12-05T13:48:07.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6179', 'Major', '2019-12-05T11:58:06.000+0000', 'Closed', '1.10.5'],
#  ['AIRFLOW-6178',
#   'Major',
#   '2019-12-05T11:40:56.000+0000',
#   'Open',
#   '2.0.0 1.10.6'],
#  ['AIRFLOW-6177',
#   'Minor',
#   '2019-12-05T11:35:46.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6176', 'Minor', '2019-12-04T23:31:11.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6175',
#   'Blocker',
#   '2019-12-04T21:59:08.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6174', 'Trivial', '2019-12-04T21:42:04.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6173',
#   'Major',
#   '2019-12-04T16:46:36.000+0000',
#   'Open',
#   '1.10.5 1.10.6'],
#  ['AIRFLOW-6172',
#   'Minor',
#   '2019-12-04T15:42:34.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6171',
#   'Major',
#   '2019-12-04T08:19:55.000+0000',
#   'Resolved',
#   '1.10.5 1.10.6'],
#  ['AIRFLOW-6170',
#   'Minor',
#   '2019-12-04T07:32:44.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6169',
#   'Trivial',
#   '2019-12-04T05:47:00.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6168',
#   'Trivial',
#   '2019-12-04T04:34:20.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6167', 'Major', '2019-12-03T20:31:56.000+0000', 'Open', '1.10.4'],
#  ['AIRFLOW-6166',
#   'Minor',
#   '2019-12-03T17:27:51.000+0000',
#   'In Progress',
#   '1.10.7'],
#  ['AIRFLOW-6165',
#   'Minor',
#   '2019-12-03T15:51:45.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6164', 'Minor', '2019-12-03T15:42:09.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6163', 'Major', '2019-12-03T14:55:51.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6162',
#   'Major',
#   '2019-12-03T11:06:15.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6161',
#   'Major',
#   '2019-12-03T04:27:00.000+0000',
#   'Open',
#   '1.10.3 2.0.0'],
#  ['AIRFLOW-6160', 'Major', '2019-12-03T01:00:47.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6159',
#   'Critical',
#   '2019-12-02T22:56:06.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6158',
#   'Minor',
#   '2019-12-02T22:51:42.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6157', 'Major', '2019-12-02T22:06:41.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6156', 'Minor', '2019-12-02T21:06:14.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6155', 'Major', '2019-12-02T19:10:47.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6154', 'Minor', '2019-12-02T17:10:05.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6153', 'Major', '2019-12-02T13:55:07.000+0000', 'Closed', '2.0.0'],
#  ['AIRFLOW-6152',
#   'Minor',
#   '2019-12-02T08:42:43.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6151',
#   'Minor',
#   '2019-12-02T08:40:15.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6150', 'Minor', '2019-12-02T08:38:34.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6149',
#   'Minor',
#   '2019-12-02T08:36:47.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6148',
#   'Minor',
#   '2019-12-02T08:34:14.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6147',
#   'Minor',
#   '2019-12-02T08:31:16.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6146',
#   'Minor',
#   '2019-12-02T08:29:16.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6145',
#   'Minor',
#   '2019-12-02T08:26:20.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6144',
#   'Minor',
#   '2019-12-02T07:21:28.000+0000',
#   'Resolved',
#   '2.0.0 1.10.6'],
#  ['AIRFLOW-6143',
#   'Major',
#   '2019-12-01T20:42:53.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6142',
#   'Major',
#   '2019-12-01T19:27:00.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6141',
#   'Major',
#   '2019-12-01T19:17:12.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6140',
#   'Major',
#   '2019-12-01T15:38:08.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6139',
#   'Major',
#   '2019-12-01T09:13:54.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6138',
#   'Major',
#   '2019-12-01T09:00:57.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6137',
#   'Major',
#   '2019-11-30T22:26:14.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6136',
#   'Major',
#   '2019-11-30T21:58:40.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6135',
#   'Major',
#   '2019-11-30T19:13:11.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6134', 'Major', '2019-11-30T18:06:08.000+0000', 'Open', '1.10.6'],
#  ['AIRFLOW-6133',
#   'Major',
#   '2019-11-30T14:18:40.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6132',
#   'Minor',
#   '2019-11-30T13:24:46.000+0000',
#   'Resolved',
#   '1.10.4'],
#  ['AIRFLOW-6131',
#   'Major',
#   '2019-11-30T12:33:29.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6130',
#   'Minor',
#   '2019-11-30T12:24:42.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6129',
#   'Major',
#   '2019-11-30T10:40:00.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-6128', 'Major', '2019-11-29T20:05:07.000+0000', 'Open', '2.0.0'],
#  ['AIRFLOW-6127',
#   'Minor',
#   '2019-11-29T14:13:59.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6126',
#   'Minor',
#   '2019-11-29T14:04:15.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6125',
#   'Minor',
#   '2019-11-29T14:00:48.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ['AIRFLOW-6124',
#   'Critical',
#   '2019-11-29T13:28:20.000+0000',
#   'Open',
#   '1.10.6'],
#  ['AIRFLOW-6123', 'Minor', '2019-11-29T13:21:31.000+0000', 'Closed', '1.10.6'],
#  ['AIRFLOW-6122',
#   'Minor',
#   '2019-11-29T13:17:41.000+0000',
#   'Resolved',
#   '1.10.6'],
#  ...]

# %%
#Reverse the data to start it from the first issue
final_data=data[::-1]

# %%
#The final data
final_data
# Out:
# [['AIRFLOW-1', 'Major', '2016-04-15T04:07:26.000+0000', 'Resolved', ''],
#  ['AIRFLOW-6', 'Major', '2016-04-22T00:04:48.000+0000', 'Closed', ''],
#  ['AIRFLOW-7', 'Minor', '2016-04-27T00:04:31.000+0000', 'Closed', ''],
#  ['AIRFLOW-9', 'Major', '2016-04-27T18:28:20.000+0000', 'Closed', ''],
#  ['AIRFLOW-10', 'Major', '2016-04-27T18:40:00.000+0000', 'Closed', ''],
#  ['AIRFLOW-11', 'Major', '2016-04-27T18:40:12.000+0000', 'Closed', ''],
#  ['AIRFLOW-12', 'Major', '2016-04-27T18:41:30.000+0000', 'Closed', ''],
#  ['AIRFLOW-13', 'Major', '2016-04-27T18:41:51.000+0000', 'Resolved', ''],
#  ['AIRFLOW-14', 'Major', '2016-04-28T14:13:53.000+0000', 'Closed', ''],
#  ['AIRFLOW-15', 'Major', '2016-04-28T14:43:00.000+0000', 'Resolved', ''],
#  ['AIRFLOW-16', 'Major', '2016-04-28T16:30:27.000+0000', 'Resolved', ''],
#  ['AIRFLOW-17', 'Major', '2016-04-28T16:40:31.000+0000', 'Closed', ''],
#  ['AIRFLOW-18', 'Critical', '2016-04-28T18:38:59.000+0000', 'Closed', ''],
#  ['AIRFLOW-19', 'Minor', '2016-04-28T21:08:00.000+0000', 'Closed', ''],
#  ['AIRFLOW-20', 'Major', '2016-04-29T13:58:17.000+0000', 'Closed', ''],
#  ['AIRFLOW-21', 'Major', '2016-04-29T16:00:50.000+0000', 'Resolved', ''],
#  ['AIRFLOW-22', 'Major', '2016-04-29T16:27:42.000+0000', 'Resolved', ''],
#  ['AIRFLOW-23', 'Major', '2016-04-29T18:59:15.000+0000', 'Closed', ''],
#  ['AIRFLOW-24', 'Major', '2016-04-29T18:59:41.000+0000', 'Closed', ''],
#  ['AIRFLOW-25', 'Trivial', '2016-05-01T00:05:48.000+0000', 'Closed', ''],
#  ['AIRFLOW-26', 'Minor', '2016-05-01T19:45:20.000+0000', 'Resolved', ''],
#  ['AIRFLOW-27', 'Major', '2016-05-02T08:49:56.000+0000', 'Closed', ''],
#  ['AIRFLOW-28', 'Minor', '2016-05-02T09:03:47.000+0000', 'Reopened', ''],
#  ['AIRFLOW-29', 'Minor', '2016-05-02T09:18:20.000+0000', 'Closed', ''],
#  ['AIRFLOW-30', 'Major', '2016-05-02T09:21:00.000+0000', 'Closed', ''],
#  ['AIRFLOW-31', 'Major', '2016-05-02T12:30:09.000+0000', 'Closed', ''],
#  ['AIRFLOW-32', 'Major', '2016-05-02T13:00:35.000+0000', 'Closed', ''],
#  ['AIRFLOW-33', 'Major', '2016-05-02T20:52:39.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-34', 'Minor', '2016-05-02T22:34:10.000+0000', 'Closed', ''],
#  ['AIRFLOW-35', 'Major', '2016-05-03T00:25:05.000+0000', 'Closed', ''],
#  ['AIRFLOW-36', 'Major', '2016-05-03T00:32:11.000+0000', 'Closed', ''],
#  ['AIRFLOW-37', 'Critical', '2016-05-03T00:48:02.000+0000', 'Closed', ''],
#  ['AIRFLOW-38', 'Minor', '2016-05-03T02:09:33.000+0000', 'Closed', ''],
#  ['AIRFLOW-39', 'Minor', '2016-05-03T10:48:56.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-40', 'Minor', '2016-05-03T11:30:49.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-41', 'Major', '2016-05-03T17:28:28.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-42', 'Major', '2016-05-03T18:56:19.000+0000', 'Closed', ''],
#  ['AIRFLOW-43', 'Critical', '2016-05-03T19:30:58.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-44', 'Major', '2016-05-03T20:27:35.000+0000', 'Closed', ''],
#  ['AIRFLOW-45', 'Major', '2016-05-03T22:28:27.000+0000', 'Closed', ''],
#  ['AIRFLOW-46', 'Major', '2016-05-04T01:23:34.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-47', 'Major', '2016-05-04T06:40:29.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-48', 'Major', '2016-05-04T17:56:01.000+0000', 'Resolved', '1.7.0'],
#  ['AIRFLOW-49', 'Minor', '2016-05-05T03:43:48.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-50', 'Major', '2016-05-05T07:15:46.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-51', 'Minor', '2016-05-05T17:41:50.000+0000', 'Closed', ''],
#  ['AIRFLOW-52', 'Major', '2016-05-05T18:08:49.000+0000', 'Closed', ''],
#  ['AIRFLOW-53', 'Major', '2016-05-05T20:41:15.000+0000', 'Closed', ''],
#  ['AIRFLOW-54', 'Minor', '2016-05-06T04:00:15.000+0000', 'Closed', ''],
#  ['AIRFLOW-55', 'Major', '2016-05-06T08:49:41.000+0000', 'Closed', ''],
#  ['AIRFLOW-56', 'Blocker', '2016-05-06T12:07:40.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-57', 'Minor', '2016-05-06T13:28:07.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-58',
#   'Trivial',
#   '2016-05-06T13:55:58.000+0000',
#   'Reopened',
#   '1.7.0'],
#  ['AIRFLOW-59', 'Minor', '2016-05-06T13:58:52.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-60', 'Minor', '2016-05-06T14:01:34.000+0000', 'Closed', ''],
#  ['AIRFLOW-61', 'Major', '2016-05-06T14:52:46.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-62', 'Major', '2016-05-06T20:16:31.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-63', 'Minor', '2016-05-06T21:38:59.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-64', 'Major', '2016-05-06T21:46:51.000+0000', 'Resolved', '1.7.0'],
#  ['AIRFLOW-65', 'Minor', '2016-05-06T22:14:34.000+0000', 'Resolved', ''],
#  ['AIRFLOW-66', 'Minor', '2016-05-06T23:19:02.000+0000', 'Closed', ''],
#  ['AIRFLOW-67', 'Major', '2016-05-07T16:33:36.000+0000', 'Closed', ''],
#  ['AIRFLOW-68', 'Major', '2016-05-07T22:47:15.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-69', 'Major', '2016-05-07T22:47:49.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-70', 'Major', '2016-05-07T22:48:21.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-71', 'Minor', '2016-05-08T08:01:00.000+0000', 'Resolved', ''],
#  ['AIRFLOW-72', 'Major', '2016-05-08T11:18:35.000+0000', 'Closed', ''],
#  ['AIRFLOW-73', 'Minor', '2016-05-08T13:38:11.000+0000', 'Closed', ''],
#  ['AIRFLOW-74',
#   'Major',
#   '2016-05-08T15:24:51.000+0000',
#   'Resolved',
#   '1.6.2 1.7.0 1.7.1'],
#  ['AIRFLOW-75', 'Minor', '2016-05-08T20:18:44.000+0000', 'Resolved', '1.7.0'],
#  ['AIRFLOW-76', 'Minor', '2016-05-08T23:23:03.000+0000', 'Resolved', '1.7.0'],
#  ['AIRFLOW-77', 'Minor', '2016-05-09T00:18:56.000+0000', 'Closed', ''],
#  ['AIRFLOW-78', 'Minor', '2016-05-09T07:01:48.000+0000', 'Closed', '1.6.2'],
#  ['AIRFLOW-79', 'Major', '2016-05-09T15:50:46.000+0000', 'Closed', ''],
#  ['AIRFLOW-80', 'Major', '2016-05-09T18:33:31.000+0000', 'Closed', ''],
#  ['AIRFLOW-81', 'Minor', '2016-05-09T18:52:40.000+0000', 'Closed', ''],
#  ['AIRFLOW-82', 'Minor', '2016-05-09T18:58:37.000+0000', 'Closed', ''],
#  ['AIRFLOW-83', 'Minor', '2016-05-09T21:46:22.000+0000', 'Resolved', ''],
#  ['AIRFLOW-84', 'Major', '2016-05-09T22:16:58.000+0000', 'Closed', ''],
#  ['AIRFLOW-85', 'Major', '2016-05-09T22:24:42.000+0000', 'Resolved', ''],
#  ['AIRFLOW-86', 'Major', '2016-05-10T01:10:15.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-87', 'Minor', '2016-05-10T02:13:01.000+0000', 'Closed', ''],
#  ['AIRFLOW-88', 'Minor', '2016-05-10T02:25:40.000+0000', 'Resolved', ''],
#  ['AIRFLOW-89', 'Minor', '2016-05-10T05:42:33.000+0000', 'Closed', ''],
#  ['AIRFLOW-90', 'Trivial', '2016-05-10T07:01:45.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-91', 'Major', '2016-05-10T10:07:07.000+0000', 'Closed', ''],
#  ['AIRFLOW-92', 'Critical', '2016-05-10T11:04:04.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-93', 'Minor', '2016-05-10T11:59:05.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-94', 'Major', '2016-05-10T13:44:19.000+0000', 'Closed', ''],
#  ['AIRFLOW-95', 'Major', '2016-05-10T13:49:00.000+0000', 'Closed', ''],
#  ['AIRFLOW-96', 'Minor', '2016-05-10T15:24:56.000+0000', 'Resolved', '1.6.2'],
#  ['AIRFLOW-97',
#   'Minor',
#   '2016-05-10T16:17:35.000+0000',
#   'Closed',
#   '1.7.0 1.9.0'],
#  ['AIRFLOW-98', 'Major', '2016-05-10T17:52:34.000+0000', 'Closed', ''],
#  ['AIRFLOW-99', 'Major', '2016-05-10T18:56:07.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-100', 'Minor', '2016-05-10T23:33:50.000+0000', 'Resolved', ''],
#  ['AIRFLOW-101', 'Minor', '2016-05-11T07:33:02.000+0000', 'Resolved', '1.7.0'],
#  ['AIRFLOW-102',
#   'Trivial',
#   '2016-05-11T09:22:16.000+0000',
#   'Resolved',
#   '1.7.1'],
#  ['AIRFLOW-103', 'Minor', '2016-05-11T10:40:58.000+0000', 'Closed', ''],
#  ['AIRFLOW-104', 'Minor', '2016-05-11T12:54:40.000+0000', 'Closed', ''],
#  ['AIRFLOW-105', 'Major', '2016-05-11T14:46:58.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-106', 'Blocker', '2016-05-11T16:44:07.000+0000', 'Closed', ''],
#  ['AIRFLOW-107', 'Major', '2016-05-11T19:50:07.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-108', 'Major', '2016-05-12T15:41:21.000+0000', 'Closed', ''],
#  ['AIRFLOW-109',
#   'Minor',
#   '2016-05-12T23:12:49.000+0000',
#   'Closed',
#   '1.6.2 1.7.1 1.8.0'],
#  ['AIRFLOW-110', 'Trivial', '2016-05-12T23:49:52.000+0000', 'Resolved', ''],
#  ['AIRFLOW-111',
#   'Major',
#   '2016-05-13T20:24:47.000+0000',
#   'Resolved',
#   '1.6.2 1.7.1.2'],
#  ['AIRFLOW-112', 'Minor', '2016-05-13T20:27:13.000+0000', 'Resolved', ''],
#  ['AIRFLOW-113', 'Major', '2016-05-13T20:29:54.000+0000', 'Closed', '1.6.2'],
#  ['AIRFLOW-114', 'Trivial', '2016-05-13T20:45:47.000+0000', 'Resolved', ''],
#  ['AIRFLOW-115', 'Minor', '2016-05-13T21:11:33.000+0000', 'Resolved', ''],
#  ['AIRFLOW-116', 'Minor', '2016-05-13T22:59:56.000+0000', 'Closed', ''],
#  ['AIRFLOW-117', 'Major', '2016-05-14T23:26:25.000+0000', 'Closed', ''],
#  ['AIRFLOW-118', 'Major', '2016-05-15T00:14:01.000+0000', 'Closed', ''],
#  ['AIRFLOW-119', 'Major', '2016-05-16T08:41:10.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-120', 'Major', '2016-05-16T08:42:16.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-121', 'Trivial', '2016-05-16T16:15:58.000+0000', 'Closed', ''],
#  ['AIRFLOW-122', 'Minor', '2016-05-16T20:09:45.000+0000', 'Closed', '1.8.0'],
#  ['AIRFLOW-123', 'Minor', '2016-05-17T00:35:42.000+0000', 'Closed', ''],
#  ['AIRFLOW-124', 'Major', '2016-05-17T07:21:01.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-125', 'Minor', '2016-05-17T18:22:48.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-126', 'Major', '2016-05-17T20:28:27.000+0000', 'Closed', ''],
#  ['AIRFLOW-127', 'Minor', '2016-05-18T10:24:38.000+0000', 'Closed', ''],
#  ['AIRFLOW-128', 'Major', '2016-05-18T10:26:47.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-129', 'Major', '2016-05-18T12:46:56.000+0000', 'Resolved', '1.7.0'],
#  ['AIRFLOW-130', 'Major', '2016-05-18T17:12:37.000+0000', 'Resolved', '1.7.0'],
#  ['AIRFLOW-131', 'Major', '2016-05-18T17:14:37.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-132', 'Major', '2016-05-18T17:39:24.000+0000', 'Closed', ''],
#  ['AIRFLOW-133', 'Minor', '2016-05-18T19:33:22.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-134', 'Major', '2016-05-18T22:14:23.000+0000', 'Closed', ''],
#  ['AIRFLOW-135', 'Minor', '2016-05-19T00:45:31.000+0000', 'Closed', ''],
#  ['AIRFLOW-136', 'Major', '2016-05-19T07:00:55.000+0000', 'Closed', ''],
#  ['AIRFLOW-137', 'Minor', '2016-05-19T09:04:03.000+0000', 'Open', ''],
#  ['AIRFLOW-138', 'Minor', '2016-05-19T09:09:34.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-139', 'Major', '2016-05-19T11:29:21.000+0000', 'Resolved', '1.7.0'],
#  ['AIRFLOW-140', 'Minor', '2016-05-19T12:54:01.000+0000', 'Resolved', ''],
#  ['AIRFLOW-141', 'Minor', '2016-05-19T13:55:38.000+0000', 'Closed', ''],
#  ['AIRFLOW-142', 'Minor', '2016-05-19T14:09:43.000+0000', 'Closed', ''],
#  ['AIRFLOW-143', 'Minor', '2016-05-19T14:17:08.000+0000', 'Closed', ''],
#  ['AIRFLOW-144', 'Major', '2016-05-19T17:47:33.000+0000', 'Closed', ''],
#  ['AIRFLOW-145', 'Major', '2016-05-19T18:42:35.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-146', 'Major', '2016-05-19T19:13:04.000+0000', 'Closed', ''],
#  ['AIRFLOW-147', 'Minor', '2016-05-19T19:47:23.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-148', 'Minor', '2016-05-19T20:26:46.000+0000', 'Closed', ''],
#  ['AIRFLOW-149', 'Major', '2016-05-19T21:09:06.000+0000', 'Resolved', ''],
#  ['AIRFLOW-150', 'Major', '2016-05-20T00:30:23.000+0000', 'Closed', ''],
#  ['AIRFLOW-151', 'Major', '2016-05-20T03:23:19.000+0000', 'Closed', ''],
#  ['AIRFLOW-152', 'Minor', '2016-05-20T06:30:31.000+0000', 'Closed', ''],
#  ['AIRFLOW-153', 'Trivial', '2016-05-20T08:18:33.000+0000', 'Closed', ''],
#  ['AIRFLOW-154', 'Minor', '2016-05-20T09:37:17.000+0000', 'Closed', ''],
#  ['AIRFLOW-155', 'Major', '2016-05-20T15:23:38.000+0000', 'Closed', ''],
#  ['AIRFLOW-156', 'Minor', '2016-05-20T17:19:53.000+0000', 'Closed', ''],
#  ['AIRFLOW-157', 'Minor', '2016-05-20T20:16:16.000+0000', 'Resolved', ''],
#  ['AIRFLOW-158', 'Major', '2016-05-20T20:16:56.000+0000', 'Resolved', ''],
#  ['AIRFLOW-159', 'Major', '2016-05-22T12:35:30.000+0000', 'Resolved', ''],
#  ['AIRFLOW-160', 'Major', '2016-05-23T00:57:20.000+0000', 'Closed', ''],
#  ['AIRFLOW-161',
#   'Major',
#   '2016-05-23T07:04:40.000+0000',
#   'Resolved',
#   '1.9.0 1.10.0'],
#  ['AIRFLOW-162', 'Trivial', '2016-05-23T08:51:41.000+0000', 'Closed', ''],
#  ['AIRFLOW-163', 'Minor', '2016-05-23T09:22:19.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-164', 'Major', '2016-05-23T09:47:56.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-165', 'Minor', '2016-05-23T13:58:20.000+0000', 'Closed', ''],
#  ['AIRFLOW-166', 'Major', '2016-05-23T23:49:46.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-167', 'Major', '2016-05-24T15:36:01.000+0000', 'Closed', ''],
#  ['AIRFLOW-168',
#   'Major',
#   '2016-05-24T16:18:11.000+0000',
#   'Resolved',
#   '1.7.1.2'],
#  ['AIRFLOW-169', 'Major', '2016-05-24T16:27:50.000+0000', 'Resolved', ''],
#  ['AIRFLOW-170', 'Minor', '2016-05-24T22:51:08.000+0000', 'Closed', ''],
#  ['AIRFLOW-171', 'Major', '2016-05-25T01:22:21.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-172', 'Major', '2016-05-25T05:22:18.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-173', 'Minor', '2016-05-25T07:27:39.000+0000', 'Closed', ''],
#  ['AIRFLOW-174', 'Minor', '2016-05-25T14:06:02.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-175',
#   'Major',
#   '2016-05-25T14:33:07.000+0000',
#   'Resolved',
#   '1.7.1.2'],
#  ['AIRFLOW-176', 'Major', '2016-05-25T15:50:07.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-177', 'Major', '2016-05-26T04:33:53.000+0000', 'Closed', ''],
#  ['AIRFLOW-178', 'Minor', '2016-05-26T04:49:43.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-179', 'Major', '2016-05-26T05:29:36.000+0000', 'Resolved', ''],
#  ['AIRFLOW-180',
#   'Major',
#   '2016-05-26T16:51:09.000+0000',
#   'Closed',
#   '1.6.2 1.7.0 1.7.1 1.7.1.2'],
#  ['AIRFLOW-181', 'Major', '2016-05-26T19:54:37.000+0000', 'Closed', ''],
#  ['AIRFLOW-182', 'Minor', '2016-05-26T23:35:45.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-183', 'Minor', '2016-05-27T05:42:35.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-184', 'Major', '2016-05-27T17:14:19.000+0000', 'Open', ''],
#  ['AIRFLOW-185', 'Minor', '2016-05-27T17:24:04.000+0000', 'Closed', ''],
#  ['AIRFLOW-186', 'Major', '2016-05-27T18:20:52.000+0000', 'Resolved', ''],
#  ['AIRFLOW-187', 'Minor', '2016-05-27T18:48:28.000+0000', 'Resolved', ''],
#  ['AIRFLOW-188', 'Major', '2016-05-29T03:26:59.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-189', 'Minor', '2016-05-29T14:24:32.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-190', 'Major', '2016-05-30T10:32:41.000+0000', 'Closed', ''],
#  ['AIRFLOW-191',
#   'Major',
#   '2016-05-30T12:20:44.000+0000',
#   'Resolved',
#   '1.7.1.2'],
#  ['AIRFLOW-192',
#   'Major',
#   '2016-05-30T12:36:05.000+0000',
#   'Resolved',
#   '1.7.1.2'],
#  ['AIRFLOW-193', 'Major', '2016-05-30T12:56:52.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-194', 'Major', '2016-05-30T13:45:42.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-195', 'Major', '2016-05-31T05:35:16.000+0000', 'Closed', ''],
#  ['AIRFLOW-196',
#   'Major',
#   '2016-05-31T11:56:02.000+0000',
#   'Closed',
#   '1.6.2 1.7.0 1.7.1 1.7.1.2 1.8.0 2.0.0'],
#  ['AIRFLOW-197', 'Trivial', '2016-05-31T19:35:59.000+0000', 'Closed', '1.6.2'],
#  ['AIRFLOW-198', 'Major', '2016-05-31T20:20:38.000+0000', 'Resolved', ''],
#  ['AIRFLOW-199',
#   'Major',
#   '2016-06-01T04:50:26.000+0000',
#   'Closed',
#   '1.8.0 2.0.0'],
#  ['AIRFLOW-200', 'Minor', '2016-06-01T07:46:30.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-201', 'Major', '2016-06-01T09:03:01.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-202', 'Major', '2016-06-01T09:17:35.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-203', 'Major', '2016-06-01T11:33:00.000+0000', 'Open', '1.7.1.2'],
#  ['AIRFLOW-204', 'Major', '2016-06-01T11:35:09.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-205', 'Minor', '2016-06-01T14:34:08.000+0000', 'Resolved', ''],
#  ['AIRFLOW-206',
#   'Trivial',
#   '2016-06-01T18:00:37.000+0000',
#   'Closed',
#   '1.7.1.2'],
#  ['AIRFLOW-207', 'Minor', '2016-06-02T16:48:02.000+0000', 'Resolved', ''],
#  ['AIRFLOW-208', 'Major', '2016-06-02T20:58:09.000+0000', 'Resolved', ''],
#  ['AIRFLOW-209', 'Major', '2016-06-03T12:57:40.000+0000', 'Closed', ''],
#  ['AIRFLOW-210', 'Minor', '2016-06-03T15:13:46.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-211', 'Minor', '2016-06-03T22:45:53.000+0000', 'Resolved', ''],
#  ['AIRFLOW-212', 'Major', '2016-06-04T00:07:12.000+0000', 'Closed', ''],
#  ['AIRFLOW-213', 'Minor', '2016-06-04T17:26:26.000+0000', 'Resolved', ''],
#  ['AIRFLOW-214', 'Major', '2016-06-06T19:30:12.000+0000', 'Closed', ''],
#  ['AIRFLOW-215',
#   'Major',
#   '2016-06-06T19:44:15.000+0000',
#   'Resolved',
#   '1.7.1.2'],
#  ['AIRFLOW-216', 'Minor', '2016-06-07T10:54:25.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-217',
#   'Minor',
#   '2016-06-07T20:03:08.000+0000',
#   'Resolved',
#   '1.7.1.2'],
#  ['AIRFLOW-218', 'Minor', '2016-06-08T02:55:16.000+0000', 'Resolved', ''],
#  ['AIRFLOW-219', 'Major', '2016-06-08T05:40:35.000+0000', 'Resolved', ''],
#  ['AIRFLOW-220', 'Minor', '2016-06-08T06:23:40.000+0000', 'Closed', ''],
#  ['AIRFLOW-221', 'Major', '2016-06-08T15:17:43.000+0000', 'Closed', ''],
#  ['AIRFLOW-222', 'Minor', '2016-06-08T18:04:48.000+0000', 'Closed', ''],
#  ['AIRFLOW-223', 'Minor', '2016-06-09T13:10:19.000+0000', 'Resolved', ''],
#  ['AIRFLOW-224', 'Major', '2016-06-09T17:29:38.000+0000', 'Closed', ''],
#  ['AIRFLOW-225', 'Major', '2016-06-09T17:47:14.000+0000', 'Closed', ''],
#  ['AIRFLOW-226', 'Minor', '2016-06-09T18:23:49.000+0000', 'Closed', ''],
#  ['AIRFLOW-227', 'Major', '2016-06-09T19:50:44.000+0000', 'Resolved', ''],
#  ['AIRFLOW-228',
#   'Major',
#   '2016-06-09T21:27:43.000+0000',
#   'Resolved',
#   '1.7.1.2'],
#  ['AIRFLOW-229', 'Minor', '2016-06-09T23:31:54.000+0000', 'Closed', '1.6.2'],
#  ['AIRFLOW-230', 'Major', '2016-06-10T04:38:09.000+0000', 'Resolved', ''],
#  ['AIRFLOW-231', 'Major', '2016-06-10T04:59:00.000+0000', 'Closed', ''],
#  ['AIRFLOW-232', 'Major', '2016-06-10T09:41:53.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-233', 'Major', '2016-06-10T13:46:00.000+0000', 'Resolved', ''],
#  ['AIRFLOW-234', 'Major', '2016-06-10T18:05:04.000+0000', 'Closed', ''],
#  ['AIRFLOW-235', 'Major', '2016-06-10T22:56:07.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-236', 'Major', '2016-06-11T19:25:52.000+0000', 'Resolved', ''],
#  ['AIRFLOW-237',
#   'Critical',
#   '2016-06-13T19:54:58.000+0000',
#   'Resolved',
#   '1.7.0 1.7.1 1.7.1.2'],
#  ['AIRFLOW-238', 'Major', '2016-06-13T22:25:09.000+0000', 'Closed', ''],
#  ['AIRFLOW-239', 'Major', '2016-06-14T18:56:57.000+0000', 'Closed', ''],
#  ['AIRFLOW-240', 'Major', '2016-06-14T19:29:04.000+0000', 'Closed', ''],
#  ['AIRFLOW-241', 'Trivial', '2016-06-14T22:13:43.000+0000', 'Resolved', ''],
#  ['AIRFLOW-242', 'Major', '2016-06-14T22:42:55.000+0000', 'Closed', ''],
#  ['AIRFLOW-243', 'Minor', '2016-06-14T22:53:07.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-244', 'Major', '2016-06-15T00:54:19.000+0000', 'Closed', ''],
#  ['AIRFLOW-245', 'Major', '2016-06-15T09:48:09.000+0000', 'Closed', ''],
#  ['AIRFLOW-246', 'Major', '2016-06-15T18:36:12.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-247', 'Minor', '2016-06-15T18:49:02.000+0000', 'Resolved', ''],
#  ['AIRFLOW-248', 'Major', '2016-06-16T08:02:20.000+0000', 'Closed', ''],
#  ['AIRFLOW-249', 'Major', '2016-06-16T16:54:43.000+0000', 'Open', ''],
#  ['AIRFLOW-250', 'Major', '2016-06-16T18:47:31.000+0000', 'Closed', ''],
#  ['AIRFLOW-251', 'Minor', '2016-06-17T00:42:17.000+0000', 'Resolved', ''],
#  ['AIRFLOW-252', 'Major', '2016-06-17T02:12:08.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-253', 'Major', '2016-06-17T06:35:40.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-254', 'Major', '2016-06-17T12:37:37.000+0000', 'Closed', ''],
#  ['AIRFLOW-255', 'Major', '2016-06-17T14:35:06.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-256', 'Major', '2016-06-17T18:53:51.000+0000', 'Closed', ''],
#  ['AIRFLOW-257', 'Critical', '2016-06-18T01:01:26.000+0000', 'Closed', ''],
#  ['AIRFLOW-258', 'Major', '2016-06-20T11:37:34.000+0000', 'Resolved', ''],
#  ['AIRFLOW-259', 'Minor', '2016-06-20T16:06:43.000+0000', 'Open', ''],
#  ['AIRFLOW-260', 'Major', '2016-06-20T16:43:51.000+0000', 'Resolved', ''],
#  ['AIRFLOW-261', 'Major', '2016-06-20T17:37:28.000+0000', 'Resolved', ''],
#  ['AIRFLOW-262', 'Minor', '2016-06-20T18:17:25.000+0000', 'Closed', ''],
#  ['AIRFLOW-263', 'Minor', '2016-06-20T22:24:29.000+0000', 'Resolved', ''],
#  ['AIRFLOW-264', 'Minor', '2016-06-21T01:09:43.000+0000', 'Resolved', ''],
#  ['AIRFLOW-265', 'Major', '2016-06-21T09:42:26.000+0000', 'Closed', ''],
#  ['AIRFLOW-266', 'Major', '2016-06-21T15:19:26.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-267', 'Minor', '2016-06-21T19:10:12.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-268', 'Minor', '2016-06-21T21:10:18.000+0000', 'Closed', ''],
#  ['AIRFLOW-269', 'Minor', '2016-06-22T04:14:53.000+0000', 'Closed', ''],
#  ['AIRFLOW-270',
#   'Major',
#   '2016-06-22T11:18:47.000+0000',
#   'Open',
#   '1.7.1.2 1.7.1.3'],
#  ['AIRFLOW-271', 'Major', '2016-06-22T21:58:02.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-272', 'Minor', '2016-06-22T23:36:42.000+0000', 'Closed', ''],
#  ['AIRFLOW-273', 'Trivial', '2016-06-23T17:14:28.000+0000', 'Resolved', ''],
#  ['AIRFLOW-274', 'Minor', '2016-06-23T17:55:40.000+0000', 'Closed', ''],
#  ['AIRFLOW-275', 'Major', '2016-06-23T19:33:19.000+0000', 'Closed', ''],
#  ['AIRFLOW-276', 'Minor', '2016-06-23T22:23:32.000+0000', 'Resolved', ''],
#  ['AIRFLOW-277', 'Major', '2016-06-24T01:46:22.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-278', 'Major', '2016-06-24T13:49:13.000+0000', 'Closed', ''],
#  ['AIRFLOW-279', 'Minor', '2016-06-24T21:27:43.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-280', 'Major', '2016-06-25T16:31:43.000+0000', 'Closed', '1.8.0'],
#  ['AIRFLOW-281', 'Major', '2016-06-27T14:54:20.000+0000', 'Closed', ''],
#  ['AIRFLOW-282',
#   'Major',
#   '2016-06-27T15:31:01.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-283', 'Minor', '2016-06-27T17:36:17.000+0000', 'Closed', ''],
#  ['AIRFLOW-284', 'Major', '2016-06-27T21:38:23.000+0000', 'Resolved', '2.0.0'],
#  ['AIRFLOW-285', 'Major', '2016-06-28T03:08:06.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-286', 'Minor', '2016-06-28T12:06:49.000+0000', 'Closed', ''],
#  ['AIRFLOW-287', 'Minor', '2016-06-28T12:21:33.000+0000', 'Closed', ''],
#  ['AIRFLOW-288', 'Major', '2016-06-28T18:08:50.000+0000', 'Resolved', ''],
#  ['AIRFLOW-289',
#   'Minor',
#   '2016-06-29T02:39:53.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-290', 'Minor', '2016-06-29T17:50:18.000+0000', 'In Progress', ''],
#  ['AIRFLOW-291', 'Major', '2016-06-29T23:30:08.000+0000', 'Closed', ''],
#  ['AIRFLOW-292', 'Minor', '2016-06-30T01:07:13.000+0000', 'Closed', ''],
#  ['AIRFLOW-293',
#   'Minor',
#   '2016-06-30T01:28:56.000+0000',
#   'Open',
#   '1.7.1.3 1.8.0'],
#  ['AIRFLOW-294', 'Minor', '2016-06-30T02:37:42.000+0000', 'Closed', ''],
#  ['AIRFLOW-295', 'Major', '2016-06-30T07:08:31.000+0000', 'Resolved', ''],
#  ['AIRFLOW-296', 'Major', '2016-06-30T12:02:20.000+0000', 'Closed', ''],
#  ['AIRFLOW-297', 'Minor', '2016-06-30T15:28:17.000+0000', 'Closed', ''],
#  ['AIRFLOW-298', 'Major', '2016-06-30T18:44:36.000+0000', 'Resolved', ''],
#  ['AIRFLOW-299', 'Minor', '2016-06-30T20:15:20.000+0000', 'Closed', ''],
#  ['AIRFLOW-300', 'Major', '2016-06-30T20:36:49.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-301',
#   'Major',
#   '2016-06-30T21:36:22.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-302', 'Major', '2016-06-30T22:13:00.000+0000', 'Closed', ''],
#  ['AIRFLOW-303', 'Minor', '2016-06-30T22:14:37.000+0000', 'Reopened', ''],
#  ['AIRFLOW-304',
#   'Minor',
#   '2016-06-30T23:48:22.000+0000',
#   'Open',
#   '1.7.1 1.8.0'],
#  ['AIRFLOW-305', 'Major', '2016-07-01T06:40:16.000+0000', 'Open', ''],
#  ['AIRFLOW-306', 'Minor', '2016-07-01T13:20:46.000+0000', 'Resolved', ''],
#  ['AIRFLOW-307',
#   'Minor',
#   '2016-07-01T14:13:57.000+0000',
#   'Resolved',
#   '1.7.1 1.7.1.3 1.8.0'],
#  ['AIRFLOW-308', 'Minor', '2016-07-01T17:58:40.000+0000', 'Closed', ''],
#  ['AIRFLOW-309', 'Major', '2016-07-02T18:58:48.000+0000', 'Resolved', ''],
#  ['AIRFLOW-310', 'Major', '2016-07-04T09:01:22.000+0000', 'Closed', ''],
#  ['AIRFLOW-311',
#   'Minor',
#   '2016-07-04T12:55:51.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-312',
#   'Major',
#   '2016-07-04T16:38:13.000+0000',
#   'Closed',
#   '1.7.1.2 1.7.1.3'],
#  ['AIRFLOW-313', 'Trivial', '2016-07-05T14:25:47.000+0000', 'Resolved', ''],
#  ['AIRFLOW-314', 'Major', '2016-07-05T21:36:54.000+0000', 'Closed', ''],
#  ['AIRFLOW-315',
#   'Trivial',
#   '2016-07-06T11:48:55.000+0000',
#   'Resolved',
#   '1.7.1.2'],
#  ['AIRFLOW-316', 'Major', '2016-07-06T21:35:05.000+0000', 'Resolved', ''],
#  ['AIRFLOW-317',
#   'Minor',
#   '2016-07-07T10:01:54.000+0000',
#   'Closed',
#   '1.7.1.2 1.7.1.3'],
#  ['AIRFLOW-318', 'Minor', '2016-07-07T23:20:15.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-319',
#   'Minor',
#   '2016-07-08T04:54:30.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-320', 'Minor', '2016-07-08T14:52:16.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-321', 'Trivial', '2016-07-09T00:57:30.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-322',
#   'Trivial',
#   '2016-07-11T10:54:13.000+0000',
#   'Resolved',
#   '2.0.0'],
#  ['AIRFLOW-323', 'Major', '2016-07-11T16:06:22.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-324', 'Major', '2016-07-11T16:10:18.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-325', 'Critical', '2016-07-11T21:41:34.000+0000', 'Closed', ''],
#  ['AIRFLOW-326', 'Major', '2016-07-11T22:30:01.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-327', 'Minor', '2016-07-12T08:55:16.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-328',
#   'Minor',
#   '2016-07-12T14:53:36.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-329',
#   'Major',
#   '2016-07-12T20:58:09.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-330', 'Minor', '2016-07-12T22:38:22.000+0000', 'Closed', ''],
#  ['AIRFLOW-331', 'Minor', '2016-07-13T03:29:57.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-332', 'Minor', '2016-07-13T17:20:22.000+0000', 'Closed', ''],
#  ['AIRFLOW-333', 'Major', '2016-07-13T23:48:46.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-334', 'Minor', '2016-07-14T13:03:15.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-335',
#   'Trivial',
#   '2016-07-14T13:37:57.000+0000',
#   'Closed',
#   '1.7.1.2'],
#  ['AIRFLOW-336', 'Major', '2016-07-14T17:20:55.000+0000', 'Resolved', ''],
#  ['AIRFLOW-337', 'Major', '2016-07-14T17:25:07.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-338', 'Minor', '2016-07-14T19:49:07.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-339', 'Major', '2016-07-15T08:36:25.000+0000', 'Resolved', ''],
#  ['AIRFLOW-340',
#   'Trivial',
#   '2016-07-15T14:24:40.000+0000',
#   'Closed',
#   '1.7.1.3'],
#  ['AIRFLOW-341', 'Major', '2016-07-15T22:11:28.000+0000', 'Resolved', ''],
#  ['AIRFLOW-342',
#   'Major',
#   '2016-07-19T07:10:43.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-343',
#   'Major',
#   '2016-07-19T16:20:00.000+0000',
#   'Resolved',
#   '1.7.1 1.8.0 2.0.0'],
#  ['AIRFLOW-344', 'Major', '2016-07-19T16:34:30.000+0000', 'Closed', ''],
#  ['AIRFLOW-345', 'Minor', '2016-07-19T17:36:02.000+0000', 'Resolved', ''],
#  ['AIRFLOW-346', 'Minor', '2016-07-19T17:36:16.000+0000', 'Closed', ''],
#  ['AIRFLOW-347', 'Minor', '2016-07-19T20:19:14.000+0000', 'Resolved', ''],
#  ['AIRFLOW-348',
#   'Minor',
#   '2016-07-20T11:30:54.000+0000',
#   'Resolved',
#   '1.7.1.2'],
#  ['AIRFLOW-349', 'Minor', '2016-07-20T18:05:49.000+0000', 'Resolved', ''],
#  ['AIRFLOW-350', 'Major', '2016-07-21T01:34:34.000+0000', 'Closed', ''],
#  ['AIRFLOW-351', 'Major', '2016-07-21T04:09:35.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-352',
#   'Major',
#   '2016-07-21T09:52:59.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-353', 'Major', '2016-07-21T18:23:33.000+0000', 'Resolved', ''],
#  ['AIRFLOW-354', 'Trivial', '2016-07-21T23:50:04.000+0000', 'Closed', ''],
#  ['AIRFLOW-355', 'Trivial', '2016-07-21T23:52:17.000+0000', 'Closed', ''],
#  ['AIRFLOW-356', 'Trivial', '2016-07-21T23:53:37.000+0000', 'Closed', ''],
#  ['AIRFLOW-357', 'Major', '2016-07-22T07:56:46.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-358', 'Major', '2016-07-23T21:38:30.000+0000', 'Resolved', ''],
#  ['AIRFLOW-359', 'Major', '2016-07-24T16:26:11.000+0000', 'Closed', ''],
#  ['AIRFLOW-360', 'Minor', '2016-07-25T06:59:44.000+0000', 'Resolved', ''],
#  ['AIRFLOW-361', 'Major', '2016-07-25T07:22:24.000+0000', 'Resolved', ''],
#  ['AIRFLOW-362', 'Major', '2016-07-25T20:41:39.000+0000', 'Resolved', ''],
#  ['AIRFLOW-363', 'Major', '2016-07-25T23:42:32.000+0000', 'Open', '1.7.1.3'],
#  ['AIRFLOW-364', 'Trivial', '2016-07-26T07:20:29.000+0000', 'Closed', '1.6.2'],
#  ['AIRFLOW-365',
#   'Minor',
#   '2016-07-26T17:28:32.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-366', 'Major', '2016-07-26T19:58:30.000+0000', 'Open', ''],
#  ['AIRFLOW-367', 'Major', '2016-07-26T22:22:26.000+0000', 'Closed', ''],
#  ['AIRFLOW-368', 'Major', '2016-07-27T07:12:16.000+0000', 'Open', ''],
#  ['AIRFLOW-369', 'Minor', '2016-07-27T11:48:46.000+0000', 'Resolved', '2.0.0'],
#  ['AIRFLOW-370', 'Minor', '2016-07-27T14:22:49.000+0000', 'Resolved', ''],
#  ['AIRFLOW-371', 'Major', '2016-07-27T14:58:57.000+0000', 'Resolved', ''],
#  ['AIRFLOW-372', 'Major', '2016-07-27T19:55:59.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-373', 'Minor', '2016-07-28T00:18:25.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-374', 'Major', '2016-07-28T01:02:08.000+0000', 'Closed', ''],
#  ['AIRFLOW-375', 'Minor', '2016-07-28T02:32:31.000+0000', 'Resolved', ''],
#  ['AIRFLOW-376', 'Minor', '2016-07-28T04:41:38.000+0000', 'Closed', ''],
#  ['AIRFLOW-377', 'Minor', '2016-07-28T04:57:42.000+0000', 'Closed', ''],
#  ['AIRFLOW-378', 'Minor', '2016-07-28T12:59:23.000+0000', 'Closed', ''],
#  ['AIRFLOW-379', 'Minor', '2016-07-28T21:37:59.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-380', 'Major', '2016-07-28T22:12:45.000+0000', 'Open', ''],
#  ['AIRFLOW-381', 'Minor', '2016-07-28T23:08:14.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-382', 'Critical', '2016-07-29T04:37:11.000+0000', 'Closed', ''],
#  ['AIRFLOW-383', 'Minor', '2016-07-29T15:30:23.000+0000', 'Closed', ''],
#  ['AIRFLOW-384', 'Minor', '2016-07-29T16:13:06.000+0000', 'Closed', ''],
#  ['AIRFLOW-385', 'Minor', '2016-07-29T18:38:44.000+0000', 'Resolved', ''],
#  ['AIRFLOW-386', 'Major', '2016-08-01T17:10:03.000+0000', 'Closed', ''],
#  ['AIRFLOW-387',
#   'Major',
#   '2016-08-02T15:19:50.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-388', 'Major', '2016-08-02T23:38:26.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-389', 'Minor', '2016-08-02T23:54:06.000+0000', 'Closed', '2.0.0'],
#  ['AIRFLOW-390', 'Trivial', '2016-08-03T00:21:33.000+0000', 'Closed', ''],
#  ['AIRFLOW-391', 'Trivial', '2016-08-03T00:43:29.000+0000', 'Closed', ''],
#  ['AIRFLOW-392', 'Major', '2016-08-03T17:52:40.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-393', 'Minor', '2016-08-03T21:22:49.000+0000', 'Resolved', ''],
#  ['AIRFLOW-394',
#   'Major',
#   '2016-08-04T16:34:39.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-395', 'Major', '2016-08-04T17:44:39.000+0000', 'Resolved', ''],
#  ['AIRFLOW-396', 'Minor', '2016-08-04T19:17:43.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-397', 'Trivial', '2016-08-04T19:41:10.000+0000', 'Closed', ''],
#  ['AIRFLOW-398', 'Minor', '2016-08-04T21:19:07.000+0000', 'Resolved', ''],
#  ['AIRFLOW-399', 'Major', '2016-08-05T05:48:27.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-400', 'Minor', '2016-08-05T22:12:05.000+0000', 'Closed', ''],
#  ['AIRFLOW-401', 'Minor', '2016-08-08T22:09:56.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-402', 'Major', '2016-08-08T23:25:56.000+0000', 'Resolved', ''],
#  ['AIRFLOW-403', 'Major', '2016-08-09T05:41:45.000+0000', 'Resolved', ''],
#  ['AIRFLOW-404', 'Major', '2016-08-09T13:02:27.000+0000', 'Resolved', '2.0.0'],
#  ['AIRFLOW-405', 'Major', '2016-08-09T18:04:49.000+0000', 'Closed', '1.7.1.2'],
#  ['AIRFLOW-406', 'Minor', '2016-08-09T23:34:47.000+0000', 'Resolved', ''],
#  ['AIRFLOW-407', 'Minor', '2016-08-10T00:45:24.000+0000', 'Resolved', ''],
#  ['AIRFLOW-408', 'Major', '2016-08-10T08:34:17.000+0000', 'Resolved', ''],
#  ['AIRFLOW-409', 'Minor', '2016-08-10T14:26:32.000+0000', 'Resolved', ''],
#  ['AIRFLOW-410', 'Major', '2016-08-10T16:54:39.000+0000', 'Resolved', ''],
#  ['AIRFLOW-411', 'Major', '2016-08-10T18:17:54.000+0000', 'Resolved', ''],
#  ['AIRFLOW-412', 'Major', '2016-08-10T22:26:28.000+0000', 'Resolved', ''],
#  ['AIRFLOW-413', 'Major', '2016-08-10T22:45:11.000+0000', 'Resolved', ''],
#  ['AIRFLOW-414', 'Major', '2016-08-11T00:47:29.000+0000', 'Resolved', ''],
#  ['AIRFLOW-415', 'Minor', '2016-08-11T01:13:40.000+0000', 'Resolved', ''],
#  ['AIRFLOW-416', 'Trivial', '2016-08-11T06:28:15.000+0000', 'Resolved', ''],
#  ['AIRFLOW-417', 'Major', '2016-08-11T18:11:57.000+0000', 'Closed', ''],
#  ['AIRFLOW-418', 'Major', '2016-08-11T18:33:47.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-419', 'Major', '2016-08-11T18:34:28.000+0000', 'Open', '1.7.1'],
#  ['AIRFLOW-420', 'Critical', '2016-08-11T23:08:29.000+0000', 'Closed', ''],
#  ['AIRFLOW-421', 'Major', '2016-08-12T15:56:54.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-422', 'Major', '2016-08-12T18:31:34.000+0000', 'Resolved', ''],
#  ['AIRFLOW-423', 'Minor', '2016-08-12T19:32:06.000+0000', 'Resolved', ''],
#  ['AIRFLOW-424', 'Trivial', '2016-08-12T19:39:38.000+0000', 'Resolved', ''],
#  ['AIRFLOW-425', 'Trivial', '2016-08-12T20:46:58.000+0000', 'Resolved', ''],
#  ['AIRFLOW-426', 'Minor', '2016-08-12T20:55:37.000+0000', 'Resolved', ''],
#  ['AIRFLOW-427', 'Minor', '2016-08-12T22:59:12.000+0000', 'Resolved', ''],
#  ['AIRFLOW-428', 'Major', '2016-08-13T23:38:50.000+0000', 'Closed', ''],
#  ['AIRFLOW-429', 'Trivial', '2016-08-14T13:42:04.000+0000', 'Resolved', ''],
#  ['AIRFLOW-430', 'Major', '2016-08-14T22:15:11.000+0000', 'Resolved', ''],
#  ['AIRFLOW-431', 'Major', '2016-08-16T02:33:24.000+0000', 'Resolved', ''],
#  ['AIRFLOW-432', 'Major', '2016-08-16T15:55:48.000+0000', 'Closed', ''],
#  ['AIRFLOW-433', 'Major', '2016-08-16T21:42:38.000+0000', 'Closed', ''],
#  ['AIRFLOW-434', 'Blocker', '2016-08-16T22:10:17.000+0000', 'Resolved', ''],
#  ['AIRFLOW-435', 'Major', '2016-08-17T01:04:09.000+0000', 'Closed', ''],
#  ['AIRFLOW-436', 'Major', '2016-08-17T11:06:08.000+0000', 'Resolved', ''],
#  ['AIRFLOW-437', 'Major', '2016-08-17T12:03:31.000+0000', 'Resolved', ''],
#  ['AIRFLOW-438', 'Major', '2016-08-17T13:31:12.000+0000', 'Closed', ''],
#  ['AIRFLOW-439', 'Trivial', '2016-08-17T13:31:15.000+0000', 'Closed', ''],
#  ['AIRFLOW-440', 'Trivial', '2016-08-17T14:27:33.000+0000', 'Resolved', ''],
#  ['AIRFLOW-441', 'Major', '2016-08-17T19:15:32.000+0000', 'Closed', ''],
#  ['AIRFLOW-442', 'Major', '2016-08-17T21:03:31.000+0000', 'Resolved', '1.7.0'],
#  ['AIRFLOW-443', 'Major', '2016-08-18T19:58:02.000+0000', 'Resolved', ''],
#  ['AIRFLOW-444', 'Minor', '2016-08-18T22:33:17.000+0000', 'Resolved', ''],
#  ['AIRFLOW-445', 'Minor', '2016-08-18T22:41:39.000+0000', 'Resolved', ''],
#  ['AIRFLOW-446', 'Trivial', '2016-08-18T23:08:36.000+0000', 'Resolved', ''],
#  ['AIRFLOW-447',
#   'Blocker',
#   '2016-08-19T07:00:20.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-448', 'Trivial', '2016-08-19T20:44:50.000+0000', 'Resolved', ''],
#  ['AIRFLOW-449', 'Trivial', '2016-08-19T23:22:11.000+0000', 'Resolved', ''],
#  ['AIRFLOW-450', 'Minor', '2016-08-20T12:49:26.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-451', 'Trivial', '2016-08-20T13:25:00.000+0000', 'Closed', ''],
#  ['AIRFLOW-452', 'Major', '2016-08-20T13:35:59.000+0000', 'Open', ''],
#  ['AIRFLOW-453', 'Major', '2016-08-21T10:12:29.000+0000', 'Resolved', ''],
#  ['AIRFLOW-454', 'Trivial', '2016-08-21T12:32:22.000+0000', 'Closed', ''],
#  ['AIRFLOW-455',
#   'Major',
#   '2016-08-22T15:17:03.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-456', 'Major', '2016-08-22T16:20:45.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-457', 'Major', '2016-08-22T18:58:13.000+0000', 'Resolved', ''],
#  ['AIRFLOW-458', 'Major', '2016-08-22T22:47:22.000+0000', 'Open', ''],
#  ['AIRFLOW-459', 'Trivial', '2016-08-23T17:34:55.000+0000', 'Closed', ''],
#  ['AIRFLOW-460', 'Major', '2016-08-24T13:33:07.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-461', 'Major', '2016-08-24T22:24:11.000+0000', 'Resolved', ''],
#  ['AIRFLOW-462', 'Major', '2016-08-25T08:10:01.000+0000', 'Closed', '1.7.0'],
#  ['AIRFLOW-463', 'Major', '2016-08-28T16:27:36.000+0000', 'Resolved', ''],
#  ['AIRFLOW-464', 'Trivial', '2016-08-29T22:32:03.000+0000', 'Resolved', ''],
#  ['AIRFLOW-465', 'Trivial', '2016-08-30T03:00:52.000+0000', 'Resolved', ''],
#  ['AIRFLOW-466', 'Trivial', '2016-08-30T06:32:01.000+0000', 'Closed', ''],
#  ['AIRFLOW-467', 'Major', '2016-08-30T06:46:59.000+0000', 'Resolved', ''],
#  ['AIRFLOW-468', 'Major', '2016-08-30T07:31:13.000+0000', 'Resolved', ''],
#  ['AIRFLOW-469', 'Trivial', '2016-08-30T08:22:15.000+0000', 'Resolved', ''],
#  ['AIRFLOW-470',
#   'Critical',
#   '2016-08-30T08:35:04.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-471',
#   'Critical',
#   '2016-08-30T08:35:19.000+0000',
#   'Open',
#   '1.7.1.3'],
#  ['AIRFLOW-472', 'Trivial', '2016-08-30T09:15:34.000+0000', 'Resolved', ''],
#  ['AIRFLOW-473', 'Major', '2016-08-30T19:13:18.000+0000', 'Resolved', ''],
#  ['AIRFLOW-474', 'Major', '2016-08-31T16:21:43.000+0000', 'Closed', ''],
#  ['AIRFLOW-475', 'Major', '2016-08-31T16:21:54.000+0000', 'Closed', ''],
#  ['AIRFLOW-476', 'Trivial', '2016-08-31T20:36:32.000+0000', 'Resolved', ''],
#  ['AIRFLOW-477', 'Minor', '2016-09-01T08:02:10.000+0000', 'Resolved', ''],
#  ['AIRFLOW-479', 'Minor', '2016-09-01T14:29:20.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-480', 'Major', '2016-09-01T16:43:21.000+0000', 'Resolved', ''],
#  ['AIRFLOW-481', 'Major', '2016-09-01T16:54:15.000+0000', 'Resolved', ''],
#  ['AIRFLOW-482', 'Major', '2016-09-02T10:09:28.000+0000', 'Closed', '1.6.2'],
#  ['AIRFLOW-483', 'Minor', '2016-09-02T12:09:31.000+0000', 'Resolved', ''],
#  ['AIRFLOW-484', 'Trivial', '2016-09-03T14:16:11.000+0000', 'Closed', ''],
#  ['AIRFLOW-485', 'Minor', '2016-09-03T16:54:10.000+0000', 'Open', '1.7.0'],
#  ['AIRFLOW-486', 'Major', '2016-09-03T18:38:02.000+0000', 'Closed', ''],
#  ['AIRFLOW-487', 'Major', '2016-09-04T12:17:55.000+0000', 'Closed', ''],
#  ['AIRFLOW-488', 'Minor', '2016-09-06T11:07:54.000+0000', 'Resolved', ''],
#  ['AIRFLOW-489', 'Major', '2016-09-06T15:11:01.000+0000', 'Resolved', ''],
#  ['AIRFLOW-490', 'Major', '2016-09-06T18:45:23.000+0000', 'Resolved', ''],
#  ['AIRFLOW-491', 'Major', '2016-09-06T20:34:16.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-492', 'Critical', '2016-09-07T21:07:31.000+0000', 'Closed', ''],
#  ['AIRFLOW-493', 'Major', '2016-09-07T21:10:03.000+0000', 'Closed', ''],
#  ['AIRFLOW-494', 'Minor', '2016-09-07T21:45:12.000+0000', 'Closed', ''],
#  ['AIRFLOW-495', 'Major', '2016-09-08T11:54:06.000+0000', 'Closed', ''],
#  ['AIRFLOW-496', 'Major', '2016-09-08T19:02:17.000+0000', 'Open', ''],
#  ['AIRFLOW-497', 'Minor', '2016-09-09T13:00:08.000+0000', 'Closed', ''],
#  ['AIRFLOW-498', 'Major', '2016-09-09T15:32:04.000+0000', 'Closed', ''],
#  ['AIRFLOW-499', 'Major', '2016-09-09T16:44:10.000+0000', 'Closed', ''],
#  ['AIRFLOW-500', 'Major', '2016-09-09T22:05:24.000+0000', 'Resolved', ''],
#  ['AIRFLOW-501', 'Minor', '2016-09-10T18:44:25.000+0000', 'Closed', ''],
#  ['AIRFLOW-502', 'Major', '2016-09-11T00:50:41.000+0000', 'Resolved', ''],
#  ['AIRFLOW-503',
#   'Critical',
#   '2016-09-11T09:02:22.000+0000',
#   'Closed',
#   '1.7.1'],
#  ['AIRFLOW-504', 'Critical', '2016-09-11T12:23:56.000+0000', 'Closed', ''],
#  ['AIRFLOW-505', 'Minor', '2016-09-11T16:24:30.000+0000', 'Closed', ''],
#  ['AIRFLOW-506', 'Trivial', '2016-09-11T16:25:39.000+0000', 'Closed', ''],
#  ['AIRFLOW-507', 'Major', '2016-09-12T13:12:44.000+0000', 'Resolved', ''],
#  ['AIRFLOW-508', 'Minor', '2016-09-12T13:15:29.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-509', 'Major', '2016-09-14T18:38:04.000+0000', 'Closed', ''],
#  ['AIRFLOW-510', 'Minor', '2016-09-14T20:17:32.000+0000', 'Resolved', ''],
#  ['AIRFLOW-511', 'Minor', '2016-09-15T21:27:53.000+0000', 'Resolved', ''],
#  ['AIRFLOW-512', 'Trivial', '2016-09-15T22:55:21.000+0000', 'Resolved', ''],
#  ['AIRFLOW-513', 'Major', '2016-09-16T13:38:59.000+0000', 'Closed', ''],
#  ['AIRFLOW-514', 'Minor', '2016-09-16T20:29:12.000+0000', 'Closed', ''],
#  ['AIRFLOW-515', 'Major', '2016-09-19T19:37:48.000+0000', 'Closed', ''],
#  ['AIRFLOW-516', 'Minor', '2016-09-19T20:01:25.000+0000', 'Resolved', ''],
#  ['AIRFLOW-517', 'Minor', '2016-09-19T22:41:17.000+0000', 'Open', ''],
#  ['AIRFLOW-518', 'Major', '2016-09-19T23:10:45.000+0000', 'Resolved', ''],
#  ['AIRFLOW-519', 'Trivial', '2016-09-20T18:17:01.000+0000', 'Resolved', ''],
#  ['AIRFLOW-520', 'Major', '2016-09-20T20:08:22.000+0000', 'Resolved', ''],
#  ['AIRFLOW-521', 'Trivial', '2016-09-20T20:12:45.000+0000', 'Resolved', ''],
#  ['AIRFLOW-522', 'Major', '2016-09-20T22:07:34.000+0000', 'Closed', ''],
#  ['AIRFLOW-523', 'Trivial', '2016-09-21T05:20:11.000+0000', 'Resolved', ''],
#  ['AIRFLOW-524', 'Minor', '2016-09-21T11:09:16.000+0000', 'Closed', ''],
#  ['AIRFLOW-525', 'Major', '2016-09-22T07:45:50.000+0000', 'Resolved', ''],
#  ['AIRFLOW-526', 'Major', '2016-09-22T17:07:22.000+0000', 'Closed', ''],
#  ['AIRFLOW-527', 'Minor', '2016-09-23T10:26:34.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-528', 'Minor', '2016-09-23T12:12:30.000+0000', 'Closed', ''],
#  ['AIRFLOW-529', 'Major', '2016-09-27T15:09:30.000+0000', 'Closed', ''],
#  ['AIRFLOW-530', 'Minor', '2016-09-28T07:28:26.000+0000', 'Resolved', ''],
#  ['AIRFLOW-531', 'Trivial', '2016-09-28T15:01:03.000+0000', 'Resolved', ''],
#  ['AIRFLOW-532', 'Major', '2016-09-29T12:12:45.000+0000', 'Resolved', ''],
#  ['AIRFLOW-533', 'Major', '2016-09-29T12:13:00.000+0000', 'Resolved', ''],
#  ['AIRFLOW-534', 'Major', '2016-09-29T16:28:15.000+0000', 'Open', ''],
#  ['AIRFLOW-535', 'Minor', '2016-09-29T18:27:52.000+0000', 'Resolved', ''],
#  ['AIRFLOW-536', 'Major', '2016-09-30T19:56:42.000+0000', 'Open', ''],
#  ['AIRFLOW-537', 'Trivial', '2016-09-30T22:02:58.000+0000', 'Resolved', ''],
#  ['AIRFLOW-538', 'Minor', '2016-10-01T16:10:15.000+0000', 'Closed', '1.10.4'],
#  ['AIRFLOW-539', 'Minor', '2016-10-01T16:12:48.000+0000', 'Closed', ''],
#  ['AIRFLOW-540', 'Minor', '2016-10-01T16:21:39.000+0000', 'Closed', ''],
#  ['AIRFLOW-541', 'Minor', '2016-10-01T19:36:30.000+0000', 'Closed', ''],
#  ['AIRFLOW-542', 'Trivial', '2016-10-01T21:24:34.000+0000', 'Resolved', ''],
#  ['AIRFLOW-543', 'Major', '2016-10-02T13:59:42.000+0000', 'Open', ''],
#  ['AIRFLOW-544', 'Major', '2016-10-03T08:52:44.000+0000', 'Resolved', ''],
#  ['AIRFLOW-545', 'Major', '2016-10-03T22:52:56.000+0000', 'Resolved', ''],
#  ['AIRFLOW-546', 'Major', '2016-10-04T16:59:05.000+0000', 'Open', '1.7.1.3'],
#  ['AIRFLOW-547', 'Trivial', '2016-10-05T13:26:30.000+0000', 'Resolved', ''],
#  ['AIRFLOW-548', 'Major', '2016-10-05T17:48:58.000+0000', 'Resolved', ''],
#  ['AIRFLOW-549', 'Major', '2016-10-05T18:03:03.000+0000', 'Resolved', ''],
#  ['AIRFLOW-550', 'Critical', '2016-10-05T19:17:17.000+0000', 'Resolved', ''],
#  ['AIRFLOW-551', 'Major', '2016-10-05T20:58:33.000+0000', 'Resolved', ''],
#  ['AIRFLOW-552', 'Major', '2016-10-05T22:19:17.000+0000', 'Resolved', ''],
#  ['AIRFLOW-553', 'Major', '2016-10-06T13:37:44.000+0000', 'Closed', ''],
#  ['AIRFLOW-554', 'Minor', '2016-10-06T14:15:29.000+0000', 'Resolved', ''],
#  ['AIRFLOW-556', 'Minor', '2016-10-06T19:22:57.000+0000', 'Resolved', ''],
#  ['AIRFLOW-557', 'Major', '2016-10-07T21:40:28.000+0000', 'Closed', ''],
#  ['AIRFLOW-558', 'Major', '2016-10-08T05:41:13.000+0000', 'Resolved', ''],
#  ['AIRFLOW-559', 'Minor', '2016-10-08T18:06:53.000+0000', 'Closed', ''],
#  ['AIRFLOW-560', 'Minor', '2016-10-09T07:05:20.000+0000', 'Resolved', ''],
#  ['AIRFLOW-561', 'Major', '2016-10-10T18:06:51.000+0000', 'Resolved', ''],
#  ['AIRFLOW-562', 'Minor', '2016-10-10T22:38:21.000+0000', 'Open', ''],
#  ['AIRFLOW-563', 'Critical', '2016-10-11T07:37:39.000+0000', 'Closed', ''],
#  ['AIRFLOW-564', 'Major', '2016-10-11T13:02:02.000+0000', 'Open', '1.7.1.3'],
#  ['AIRFLOW-565',
#   'Major',
#   '2016-10-11T16:52:25.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-566', 'Major', '2016-10-13T11:43:22.000+0000', 'Resolved', ''],
#  ['AIRFLOW-567', 'Trivial', '2016-10-13T12:43:02.000+0000', 'Resolved', ''],
#  ['AIRFLOW-568', 'Major', '2016-10-13T22:21:50.000+0000', 'Resolved', '2.0.0'],
#  ['AIRFLOW-569', 'Major', '2016-10-14T16:30:11.000+0000', 'Open', '1.7.1.2'],
#  ['AIRFLOW-570', 'Minor', '2016-10-14T22:47:17.000+0000', 'Resolved', ''],
#  ['AIRFLOW-571', 'Major', '2016-10-14T22:48:09.000+0000', 'Closed', ''],
#  ['AIRFLOW-572', 'Major', '2016-10-16T04:41:08.000+0000', 'Resolved', ''],
#  ['AIRFLOW-573', 'Major', '2016-10-16T07:51:47.000+0000', 'Closed', '2.0.0'],
#  ['AIRFLOW-574', 'Major', '2016-10-16T23:01:12.000+0000', 'Open', '1.7.1.3'],
#  ['AIRFLOW-575', 'Minor', '2016-10-16T23:19:57.000+0000', 'Resolved', ''],
#  ['AIRFLOW-576', 'Minor', '2016-10-17T03:04:36.000+0000', 'Closed', ''],
#  ['AIRFLOW-577', 'Major', '2016-10-17T09:00:23.000+0000', 'Closed', ''],
#  ['AIRFLOW-578', 'Major', '2016-10-17T22:47:55.000+0000', 'Closed', ''],
#  ['AIRFLOW-579', 'Trivial', '2016-10-18T08:22:47.000+0000', 'Resolved', ''],
#  ['AIRFLOW-580', 'Trivial', '2016-10-18T08:33:16.000+0000', 'Resolved', ''],
#  ['AIRFLOW-581', 'Major', '2016-10-18T12:39:20.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-582', 'Major', '2016-10-19T17:57:11.000+0000', 'Closed', ''],
#  ['AIRFLOW-583', 'Minor', '2016-10-20T18:48:32.000+0000', 'Closed', ''],
#  ['AIRFLOW-584',
#   'Major',
#   '2016-10-20T20:13:31.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-585', 'Major', '2016-10-21T22:55:25.000+0000', 'Resolved', ''],
#  ['AIRFLOW-586', 'Major', '2016-10-23T05:54:31.000+0000', 'Resolved', ''],
#  ['AIRFLOW-587', 'Critical', '2016-10-23T08:15:28.000+0000', 'Closed', ''],
#  ['AIRFLOW-588', 'Major', '2016-10-23T08:17:13.000+0000', 'Closed', ''],
#  ['AIRFLOW-589', 'Major', '2016-10-23T08:18:45.000+0000', 'Closed', ''],
#  ['AIRFLOW-590', 'Trivial', '2016-10-23T11:20:32.000+0000', 'Resolved', ''],
#  ['AIRFLOW-591', 'Minor', '2016-10-23T21:41:44.000+0000', 'Resolved', ''],
#  ['AIRFLOW-592', 'Major', '2016-10-24T06:54:07.000+0000', 'Resolved', ''],
#  ['AIRFLOW-593', 'Minor', '2016-10-25T00:06:21.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-594', 'Minor', '2016-10-25T09:01:24.000+0000', 'Closed', ''],
#  ['AIRFLOW-595', 'Major', '2016-10-25T11:42:33.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-596', 'Minor', '2016-10-25T19:47:39.000+0000', 'Closed', ''],
#  ['AIRFLOW-597', 'Major', '2016-10-25T22:42:17.000+0000', 'Resolved', ''],
#  ['AIRFLOW-598',
#   'Critical',
#   '2016-10-26T13:31:27.000+0000',
#   'Closed',
#   '1.7.1.3'],
#  ['AIRFLOW-599', 'Minor', '2016-10-26T15:26:16.000+0000', 'Resolved', ''],
#  ['AIRFLOW-600', 'Minor', '2016-10-26T23:05:58.000+0000', 'Resolved', ''],
#  ['AIRFLOW-601', 'Major', '2016-10-27T03:30:35.000+0000', 'Closed', ''],
#  ['AIRFLOW-602', 'Major', '2016-10-27T23:51:07.000+0000', 'Closed', ''],
#  ['AIRFLOW-603', 'Major', '2016-10-28T09:15:54.000+0000', 'Open', '1.7.1.3'],
#  ['AIRFLOW-604', 'Major', '2016-10-29T17:11:40.000+0000', 'Resolved', ''],
#  ['AIRFLOW-605', 'Minor', '2016-10-30T19:46:29.000+0000', 'Closed', ''],
#  ['AIRFLOW-606', 'Minor', '2016-10-30T22:52:08.000+0000', 'Resolved', ''],
#  ['AIRFLOW-607',
#   'Blocker',
#   '2016-10-31T16:26:09.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-608',
#   'Critical',
#   '2016-10-31T19:39:59.000+0000',
#   'Resolved',
#   '1.7.1'],
#  ['AIRFLOW-609', 'Trivial', '2016-10-31T20:54:29.000+0000', 'Resolved', ''],
#  ['AIRFLOW-610', 'Major', '2016-11-01T09:27:30.000+0000', 'Resolved', ''],
#  ['AIRFLOW-611', 'Minor', '2016-11-01T17:27:26.000+0000', 'Resolved', ''],
#  ['AIRFLOW-612', 'Major', '2016-11-02T18:40:52.000+0000', 'Resolved', ''],
#  ['AIRFLOW-613', 'Trivial', '2016-11-02T20:05:42.000+0000', 'Resolved', ''],
#  ['AIRFLOW-614', 'Trivial', '2016-11-03T04:37:15.000+0000', 'Resolved', ''],
#  ['AIRFLOW-615', 'Trivial', '2016-11-03T16:59:36.000+0000', 'Resolved', ''],
#  ['AIRFLOW-616', 'Trivial', '2016-11-04T13:50:56.000+0000', 'Resolved', ''],
#  ['AIRFLOW-617', 'Trivial', '2016-11-04T13:55:09.000+0000', 'Resolved', ''],
#  ['AIRFLOW-618', 'Major', '2016-11-07T15:15:18.000+0000', 'Resolved', ''],
#  ['AIRFLOW-619', 'Major', '2016-11-09T17:34:16.000+0000', 'Resolved', '2.0.0'],
#  ['AIRFLOW-620', 'Major', '2016-11-09T18:16:50.000+0000', 'Open', ''],
#  ['AIRFLOW-621', 'Minor', '2016-11-10T01:29:06.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-622',
#   'Critical',
#   '2016-11-10T11:49:04.000+0000',
#   'Closed',
#   '1.6.2'],
#  ['AIRFLOW-623', 'Major', '2016-11-11T22:29:15.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-624', 'Major', '2016-11-13T21:34:19.000+0000', 'Closed', ''],
#  ['AIRFLOW-625', 'Major', '2016-11-14T11:46:57.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-626', 'Minor', '2016-11-14T19:24:39.000+0000', 'Closed', ''],
#  ['AIRFLOW-627', 'Major', '2016-11-14T20:24:36.000+0000', 'Closed', '1.8.0'],
#  ['AIRFLOW-628', 'Minor', '2016-11-15T01:05:03.000+0000', 'Closed', ''],
#  ['AIRFLOW-629', 'Major', '2016-11-15T02:15:56.000+0000', 'Resolved', ''],
#  ['AIRFLOW-630',
#   'Major',
#   '2016-11-15T12:22:00.000+0000',
#   'Resolved',
#   '1.7.1.2 1.7.1.3'],
#  ['AIRFLOW-631', 'Major', '2016-11-15T15:57:57.000+0000', 'Resolved', ''],
#  ['AIRFLOW-632', 'Major', '2016-11-15T18:13:52.000+0000', 'Resolved', ''],
# ...
#  ['AIRFLOW-805', 'Minor', '2017-01-25T16:36:41.000+0000', 'Closed', ''],
#  ['AIRFLOW-806',
#   'Trivial',
#   '2017-01-25T19:20:33.000+0000',
#   'Resolved',
#   '1.7.1.3'],
#  ['AIRFLOW-807',
#   'Major',
#   '2017-01-25T19:27:39.000+0000',
#   'Resolved',
#   '1.8.02'],
#  ['AIRFLOW-808', 'Minor', '2017-01-25T20:48:48.000+0000', 'Resolved', ''],
#  ['AIRFLOW-809', 'Major', '2017-01-25T22:08:53.000+0000', 'Resolved', ''],
#  ['AIRFLOW-810', 'Major', '2017-01-26T12:59:07.000+0000', 'Closed', ''],
#  ['AIRFLOW-811', 'Minor', '2017-01-26T23:20:16.000+0000', 'Closed', ''],
#  ['AIRFLOW-812', 'Major', '2017-01-27T08:28:26.000+0000', 'Resolved', ''],
#  ['AIRFLOW-813', 'Major', '2017-01-27T18:34:50.000+0000', 'Resolved', ''],
#  ['AIRFLOW-814', 'Trivial', '2017-01-27T23:48:12.000+0000', 'Resolved', ''],
#  ['AIRFLOW-815', 'Minor', '2017-01-29T09:21:25.000+0000', 'Resolved', ''],
#  ['AIRFLOW-816', 'Major', '2017-01-30T11:09:06.000+0000', 'Resolved', ''],
#  ['AIRFLOW-817', 'Major', '2017-01-30T11:10:13.000+0000', 'Resolved', ''],
#  ['AIRFLOW-818', 'Major', '2017-01-30T11:15:24.000+0000', 'Open', ''],
#  ['AIRFLOW-819', 'Minor', '2017-01-30T22:27:49.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-820', 'Major', '2017-01-30T23:12:22.000+0000', 'In Progress', ''],
#  ['AIRFLOW-821',
#   'Blocker',
#   '2017-01-31T10:19:04.000+0000',
#   'Resolved',
#   '1.8.05'],
#  ['AIRFLOW-822', 'Major', '2017-01-31T11:16:43.000+0000', 'Resolved', ''],
#  ['AIRFLOW-823', 'Minor', '2017-02-01T12:35:22.000+0000', 'Resolved', ''],
#  ['AIRFLOW-824', 'Minor', '2017-02-01T12:38:17.000+0000', 'Closed', ''],
#  ['AIRFLOW-825', 'Major', '2017-02-01T15:45:14.000+0000', 'Open', ''],
#  ['AIRFLOW-826', 'Major', '2017-02-01T16:01:50.000+0000', 'Closed', ''],
#  ['AIRFLOW-827', 'Major', '2017-02-02T12:33:17.000+0000', 'Closed', ''],
#  ['AIRFLOW-828', 'Major', '2017-02-02T14:36:15.000+0000', 'Closed', ''],
#  ['AIRFLOW-829', 'Major', '2017-02-02T15:06:58.000+0000', 'Resolved', ''],
#  ['AIRFLOW-830', 'Minor', '2017-02-02T15:22:10.000+0000', 'Resolved', ''],
#  ['AIRFLOW-831', 'Critical', '2017-02-02T16:27:31.000+0000', 'Resolved', ''],
#  ['AIRFLOW-832', 'Major', '2017-02-02T19:37:10.000+0000', 'Resolved', ''],
#  ['AIRFLOW-833', 'Major', '2017-02-02T20:12:43.000+0000', 'Closed', ''],
#  ['AIRFLOW-834',
#   'Minor',
#   '2017-02-03T13:59:21.000+0000',
#   'Resolved',
#   '1.8.0 1.8.05'],
#  ['AIRFLOW-835',
#   'Minor',
#   '2017-02-03T18:09:05.000+0000',
#   'Closed',
#   '1.7.1 1.9.0'],
#  ['AIRFLOW-836', 'Major', '2017-02-03T23:11:20.000+0000', 'Resolved', ''],
#  ['AIRFLOW-837', 'Trivial', '2017-02-04T00:01:06.000+0000', 'Resolved', ''],
#  ['AIRFLOW-838', 'Minor', '2017-02-04T00:02:50.000+0000', 'Resolved', ''],
#  ['AIRFLOW-839', 'Minor', '2017-02-05T06:18:04.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-840', 'Major', '2017-02-06T12:35:03.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-841', 'Major', '2017-02-06T14:10:29.000+0000', 'Closed', ''],
#  ['AIRFLOW-842',
#   'Minor',
#   '2017-02-06T15:01:10.000+0000',
#   'Resolved',
#   '1.8.0 1.8.05'],
#  ['AIRFLOW-843', 'Minor', '2017-02-06T15:47:18.000+0000', 'Resolved', ''],
#  ['AIRFLOW-844', 'Blocker', '2017-02-06T22:54:22.000+0000', 'Resolved', ''],
#  ['AIRFLOW-845', 'Major', '2017-02-07T09:46:43.000+0000', 'Closed', ''],
#  ['AIRFLOW-846', 'Blocker', '2017-02-07T11:43:15.000+0000', 'Closed', ''],
#  ['AIRFLOW-847', 'Blocker', '2017-02-07T13:45:03.000+0000', 'Resolved', ''],
#  ['AIRFLOW-848', 'Minor', '2017-02-07T21:07:04.000+0000', 'Open', '1.7.1.3'],
#  ['AIRFLOW-849', 'Minor', '2017-02-07T21:52:52.000+0000', 'Closed', ''],
#  ['AIRFLOW-850', 'Major', '2017-02-07T23:36:29.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-851', 'Major', '2017-02-08T14:24:16.000+0000', 'Closed', ''],
#  ['AIRFLOW-852', 'Major', '2017-02-08T16:47:55.000+0000', 'Closed', ''],
#  ['AIRFLOW-853', 'Major', '2017-02-09T17:18:14.000+0000', 'Resolved', '2.0.0'],
#  ['AIRFLOW-854', 'Major', '2017-02-09T17:58:55.000+0000', 'Resolved', ''],
#  ['AIRFLOW-855', 'Major', '2017-02-09T20:22:30.000+0000', 'Closed', ''],
#  ['AIRFLOW-856',
#   'Blocker',
#   '2017-02-09T21:29:23.000+0000',
#   'Resolved',
#   '1.8.02'],
#  ['AIRFLOW-857', 'Minor', '2017-02-09T22:49:11.000+0000', 'Resolved', ''],
#  ['AIRFLOW-858', 'Minor', '2017-02-10T04:18:33.000+0000', 'Resolved', ''],
#  ['AIRFLOW-859', 'Major', '2017-02-10T18:28:17.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-860', 'Major', '2017-02-10T21:01:26.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-861', 'Major', '2017-02-10T21:24:13.000+0000', 'Resolved', ''],
#  ['AIRFLOW-862', 'Major', '2017-02-11T00:28:22.000+0000', 'Resolved', ''],
#  ['AIRFLOW-863',
#   'Minor',
#   '2017-02-11T17:48:51.000+0000',
#   'Resolved',
#   '1.8.03'],
#  ['AIRFLOW-864', 'Major', '2017-02-12T01:07:59.000+0000', 'Open', ''],
#  ['AIRFLOW-865', 'Trivial', '2017-02-12T05:43:54.000+0000', 'Resolved', ''],
#  ['AIRFLOW-866', 'Minor', '2017-02-12T10:50:19.000+0000', 'Resolved', ''],
#  ['AIRFLOW-867', 'Major', '2017-02-12T11:03:45.000+0000', 'Closed', ''],
#  ['AIRFLOW-868', 'Trivial', '2017-02-12T22:39:58.000+0000', 'Resolved', ''],
#  ['AIRFLOW-869', 'Major', '2017-02-13T01:51:04.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-870', 'Major', '2017-02-13T02:20:46.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-871',
#   'Trivial',
#   '2017-02-13T14:20:40.000+0000',
#   'Resolved',
#   '1.8.0 1.8.1 2.0.0'],
#  ['AIRFLOW-872', 'Major', '2017-02-13T20:14:40.000+0000', 'Closed', '1.8.0'],
#  ['AIRFLOW-873', 'Minor', '2017-02-14T00:05:58.000+0000', 'Closed', ''],
#  ['AIRFLOW-874',
#   'Critical',
#   '2017-02-14T04:38:16.000+0000',
#   'Closed',
#   '1.7.1.3'],
#  ['AIRFLOW-875', 'Minor', '2017-02-14T04:52:32.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-876', 'Minor', '2017-02-14T16:34:07.000+0000', 'Closed', ''],
#  ['AIRFLOW-877',
#   'Critical',
#   '2017-02-14T21:06:58.000+0000',
#   'Closed',
#   '1.8.0'],
#  ['AIRFLOW-878', 'Major', '2017-02-15T13:13:52.000+0000', 'Closed', ''],
#  ['AIRFLOW-879', 'Major', '2017-02-16T02:13:30.000+0000', 'Closed', ''],
#  ['AIRFLOW-880', 'Major', '2017-02-16T23:02:11.000+0000', 'Resolved', ''],
#  ['AIRFLOW-881', 'Trivial', '2017-02-17T02:11:24.000+0000', 'Resolved', ''],
#  ['AIRFLOW-882', 'Trivial', '2017-02-17T02:35:27.000+0000', 'Resolved', ''],
#  ['AIRFLOW-883', 'Minor', '2017-02-17T02:58:08.000+0000', 'Closed', '1.10.3'],
#  ['AIRFLOW-884', 'Major', '2017-02-17T15:41:40.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-885', 'Trivial', '2017-02-18T00:29:35.000+0000', 'Resolved', ''],
#  ['AIRFLOW-886', 'Major', '2017-02-18T23:08:07.000+0000', 'Resolved', ''],
#  ['AIRFLOW-887', 'Minor', '2017-02-18T23:17:20.000+0000', 'Resolved', ''],
#  ['AIRFLOW-888', 'Major', '2017-02-19T14:59:40.000+0000', 'Closed', ''],
#  ['AIRFLOW-889', 'Trivial', '2017-02-19T18:06:15.000+0000', 'Resolved', ''],
#  ['AIRFLOW-890', 'Major', '2017-02-21T08:06:12.000+0000', 'Closed', ''],
#  ['AIRFLOW-891', 'Minor', '2017-02-21T23:31:03.000+0000', 'Resolved', ''],
#  ['AIRFLOW-892',
#   'Critical',
#   '2017-02-22T09:21:22.000+0000',
#   'Resolved',
#   '1.8.0'],
#  ['AIRFLOW-893', 'Blocker', '2017-02-22T21:17:38.000+0000', 'Resolved', ''],
#  ['AIRFLOW-894',
#   'Blocker',
#   '2017-02-23T15:57:26.000+0000',
#   'Closed',
#   '1.7.1.3'],
#  ['AIRFLOW-895',
#   'Major',
#   '2017-02-23T20:41:49.000+0000',
#   'Resolved',
#   '1.8.04'],
#  ['AIRFLOW-896', 'Major', '2017-02-23T20:53:05.000+0000', 'Resolved', ''],
#  ['AIRFLOW-897',
#   'Blocker',
#   '2017-02-23T21:28:30.000+0000',
#   'Closed',
#   '1.8.04'],
#  ['AIRFLOW-898', 'Trivial', '2017-02-23T21:55:09.000+0000', 'Closed', '1.8.0'],
#  ['AIRFLOW-899', 'Major', '2017-02-23T22:35:05.000+0000', 'Resolved', ''],
#  ['AIRFLOW-900', 'Major', '2017-02-24T03:16:46.000+0000', 'Resolved', ''],
#  ['AIRFLOW-901', 'Major', '2017-02-24T10:23:14.000+0000', 'Open', '1.8.0'],
#  ['AIRFLOW-902', 'Minor', '2017-02-24T10:42:11.000+0000', 'Closed', '2.0.0'],
#  ['AIRFLOW-903', 'Minor', '2017-02-24T14:54:17.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-904', 'Major', '2017-02-24T19:28:34.000+0000', 'Closed', ''],
#  ['AIRFLOW-905', 'Minor', '2017-02-24T19:51:52.000+0000', 'Closed', ''],
#  ['AIRFLOW-906', 'Minor', '2017-02-24T21:33:50.000+0000', 'Resolved', ''],
#  ['AIRFLOW-907', 'Major', '2017-02-24T21:58:12.000+0000', 'Closed', ''],
#  ['AIRFLOW-908', 'Major', '2017-02-24T22:22:09.000+0000', 'Resolved', ''],
#  ['AIRFLOW-909', 'Trivial', '2017-02-25T06:21:33.000+0000', 'Open', ''],
#  ['AIRFLOW-910',
#   'Blocker',
#   '2017-02-25T18:24:45.000+0000',
#   'Resolved',
#   '1.8.04'],
#  ['AIRFLOW-911',
#   'Major',
#   '2017-02-25T19:16:08.000+0000',
#   'Resolved',
#   '1.8.04'],
#  ['AIRFLOW-912', 'Major', '2017-02-25T19:28:13.000+0000', 'Open', '1.8.04'],
#  ['AIRFLOW-913', 'Major', '2017-02-25T19:31:51.000+0000', 'Open', '1.8.04'],
#  ['AIRFLOW-914', 'Major', '2017-02-25T20:13:40.000+0000', 'Open', ''],
#  ['AIRFLOW-915', 'Minor', '2017-02-26T03:19:39.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-916',
#   'Trivial',
#   '2017-02-26T13:43:53.000+0000',
#   'Resolved',
#   '1.8.0'],
#  ['AIRFLOW-917', 'Trivial', '2017-02-26T18:27:07.000+0000', 'Resolved', ''],
#  ['AIRFLOW-918', 'Minor', '2017-02-26T19:41:44.000+0000', 'Open', '1.7.1.3'],
#  ['AIRFLOW-919', 'Major', '2017-02-27T19:05:39.000+0000', 'Resolved', ''],
#  ['AIRFLOW-920',
#   'Major',
#   '2017-02-27T19:21:59.000+0000',
#   'Resolved',
#   '1.8.04'],
#  ['AIRFLOW-921', 'Blocker', '2017-02-27T19:25:49.000+0000', 'Resolved', ''],
#  ['AIRFLOW-922', 'Minor', '2017-02-27T23:07:18.000+0000', 'Open', ''],
#  ['AIRFLOW-923', 'Trivial', '2017-02-28T19:17:39.000+0000', 'Resolved', ''],
#  ['AIRFLOW-924', 'Major', '2017-02-28T20:05:52.000+0000', 'Resolved', ''],
#  ['AIRFLOW-925', 'Major', '2017-02-28T20:11:20.000+0000', 'Resolved', ''],
#  ['AIRFLOW-926',
#   'Major',
#   '2017-02-28T23:59:07.000+0000',
#   'Resolved',
#   '1.7.1.3 1.8.0'],
#  ['AIRFLOW-927',
#   'Major',
#   '2017-03-01T10:08:38.000+0000',
#   'Resolved',
#   '1.7.1.3 1.8.0'],
#  ['AIRFLOW-928', 'Major', '2017-03-01T15:10:12.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-929', 'Minor', '2017-03-01T16:21:49.000+0000', 'Resolved', ''],
#  ['AIRFLOW-930', 'Major', '2017-03-01T17:46:18.000+0000', 'Closed', '1.8.0'],
#  ['AIRFLOW-931',
#   'Major',
#   '2017-03-01T18:43:40.000+0000',
#   'Resolved',
#   '1.8.0 1.8.04'],
#  ['AIRFLOW-932', 'Blocker', '2017-03-01T18:54:30.000+0000', 'Resolved', ''],
#  ['AIRFLOW-933', 'Major', '2017-03-01T21:35:57.000+0000', 'Resolved', ''],
#  ['AIRFLOW-934',
#   'Blocker',
#   '2017-03-02T03:32:09.000+0000',
#   'Resolved',
#   '1.6.2'],
#  ['AIRFLOW-935',
#   'Major',
#   '2017-03-02T13:28:47.000+0000',
#   'Resolved',
#   '1.8.0 1.9.0'],
#  ['AIRFLOW-936', 'Major', '2017-03-02T21:54:37.000+0000', 'Resolved', ''],
#  ['AIRFLOW-937', 'Major', '2017-03-02T21:54:37.000+0000', 'Closed', ''],
#  ['AIRFLOW-938', 'Major', '2017-03-03T19:11:43.000+0000', 'Resolved', ''],
#  ['AIRFLOW-939', 'Major', '2017-03-03T20:04:11.000+0000', 'Closed', ''],
#  ['AIRFLOW-940', 'Major', '2017-03-03T22:51:18.000+0000', 'Closed', ''],
#  ['AIRFLOW-941',
#   'Major',
#   '2017-03-04T16:46:16.000+0000',
#   'Resolved',
#   '1.8.04'],
#  ['AIRFLOW-942', 'Major', '2017-03-06T01:33:42.000+0000', 'Resolved', ''],
#  ['AIRFLOW-943', 'Major', '2017-03-06T01:43:31.000+0000', 'Resolved', ''],
#  ['AIRFLOW-944',
#   'Major',
#   '2017-03-06T14:05:58.000+0000',
#   'Resolved',
#   '1.7.1.3 1.8.04'],
#  ['AIRFLOW-945', 'Major', '2017-03-06T20:00:36.000+0000', 'Resolved', '1.9.0'],
#  ['AIRFLOW-946', 'Minor', '2017-03-07T02:38:13.000+0000', 'In Progress', ''],
#  ['AIRFLOW-947', 'Minor', '2017-03-07T05:04:26.000+0000', 'Resolved', ''],
#  ['AIRFLOW-948', 'Major', '2017-03-07T07:50:19.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-949', 'Major', '2017-03-07T14:48:39.000+0000', 'Closed', '1.8.04'],
#  ['AIRFLOW-950', 'Minor', '2017-03-07T15:21:15.000+0000', 'Resolved', ''],
#  ['AIRFLOW-951', 'Minor', '2017-03-07T18:19:58.000+0000', 'Closed', ''],
#  ['AIRFLOW-952', 'Minor', '2017-03-07T23:05:35.000+0000', 'Resolved', ''],
#  ['AIRFLOW-953', 'Major', '2017-03-08T01:39:21.000+0000', 'Open', ''],
#  ['AIRFLOW-954', 'Major', '2017-03-08T01:48:05.000+0000', 'Resolved', ''],
#  ['AIRFLOW-955', 'Major', '2017-03-08T03:19:59.000+0000', 'Open', ''],
#  ['AIRFLOW-956', 'Minor', '2017-03-08T21:40:03.000+0000', 'Resolved', ''],
#  ['AIRFLOW-957', 'Major', '2017-03-09T09:11:20.000+0000', 'Open', ''],
#  ['AIRFLOW-958', 'Trivial', '2017-03-09T12:49:41.000+0000', 'Resolved', ''],
#  ['AIRFLOW-959', 'Trivial', '2017-03-09T19:25:57.000+0000', 'Resolved', ''],
#  ['AIRFLOW-960', 'Trivial', '2017-03-09T19:26:29.000+0000', 'Resolved', ''],
#  ['AIRFLOW-961', 'Major', '2017-03-09T19:57:44.000+0000', 'Resolved', ''],
#  ['AIRFLOW-962', 'Major', '2017-03-10T07:37:38.000+0000', 'Closed', ''],
#  ['AIRFLOW-963', 'Minor', '2017-03-10T08:25:46.000+0000', 'Resolved', ''],
#  ['AIRFLOW-964', 'Minor', '2017-03-10T09:33:28.000+0000', 'Closed', ''],
#  ['AIRFLOW-965', 'Major', '2017-03-10T18:13:23.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-966', 'Major', '2017-03-10T18:27:39.000+0000', 'Resolved', ''],
#  ['AIRFLOW-967', 'Major', '2017-03-10T19:12:09.000+0000', 'Resolved', ''],
#  ['AIRFLOW-968', 'Blocker', '2017-03-10T21:10:43.000+0000', 'Closed', ''],
#  ['AIRFLOW-969', 'Minor', '2017-03-10T21:42:03.000+0000', 'Resolved', ''],
#  ['AIRFLOW-970', 'Major', '2017-03-11T00:46:51.000+0000', 'Open', ''],
#  ['AIRFLOW-971',
#   'Major',
#   '2017-03-11T20:45:12.000+0000',
#   'Open',
#   '1.7.1 1.8.0'],
#  ['AIRFLOW-972', 'Minor', '2017-03-11T22:47:42.000+0000', 'Open', '1.7.1'],
#  ['AIRFLOW-973', 'Minor', '2017-03-12T04:04:17.000+0000', 'Closed', ''],
#  ['AIRFLOW-974', 'Major', '2017-03-13T15:00:43.000+0000', 'Resolved', ''],
#  ['AIRFLOW-975', 'Minor', '2017-03-13T17:27:26.000+0000', 'Closed', ''],
#  ['AIRFLOW-976', 'Major', '2017-03-13T20:45:54.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-977', 'Major', '2017-03-13T22:01:32.000+0000', 'Closed', '1.7.1'],
#  ['AIRFLOW-978', 'Major', '2017-03-14T00:32:47.000+0000', 'Closed', ''],
#  ['AIRFLOW-979', 'Trivial', '2017-03-14T08:42:04.000+0000', 'Resolved', ''],
#  ['AIRFLOW-980', 'Major', '2017-03-14T17:19:54.000+0000', 'Closed', '1.7.1.3'],
#  ['AIRFLOW-981',
#   'Critical',
#   '2017-03-14T18:33:04.000+0000',
#   'Closed',
#   '1.7.1.3'],
#  ['AIRFLOW-982', 'Minor', '2017-03-14T20:03:41.000+0000', 'Resolved', ''],
#  ['AIRFLOW-983', 'Major', '2017-03-14T20:19:50.000+0000', 'Open', '1.8.1'],
#  ['AIRFLOW-984', 'Minor', '2017-03-14T20:45:56.000+0000', 'Resolved', ''],
#  ['AIRFLOW-985', 'Major', '2017-03-14T21:13:30.000+0000', 'Resolved', ''],
#  ['AIRFLOW-986',
#   'Minor',
#   '2017-03-15T05:38:31.000+0000',
#   'Resolved',
#   '1.10.3'],
#  ['AIRFLOW-987', 'Major', '2017-03-15T05:58:45.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-988', 'Major', '2017-03-15T15:34:41.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-989',
#   'Critical',
#   '2017-03-15T20:47:57.000+0000',
#   'Resolved',
#   '1.8.0'],
#  ['AIRFLOW-990', 'Major', '2017-03-15T22:13:04.000+0000', 'Resolved', '1.7.1'],
#  ['AIRFLOW-991', 'Major', '2017-03-16T00:39:36.000+0000', 'Resolved', ''],
#  ['AIRFLOW-992', 'Critical', '2017-03-16T01:22:40.000+0000', 'Closed', ''],
#  ['AIRFLOW-993', 'Minor', '2017-03-16T03:11:44.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-994', 'Trivial', '2017-03-16T13:17:21.000+0000', 'Resolved', ''],
#  ['AIRFLOW-995', 'Minor', '2017-03-16T13:36:38.000+0000', 'Resolved', '1.8.0'],
#  ['AIRFLOW-996', 'Trivial', '2017-03-16T18:06:21.000+0000', 'Closed', '1.8.0'],
#  ['AIRFLOW-997', 'Minor', '2017-03-16T20:31:57.000+0000', 'Resolved', ''],
#  ['AIRFLOW-998', 'Major', '2017-03-17T17:18:55.000+0000', 'Open', ''],
#  ['AIRFLOW-999', 'Minor', '2017-03-17T18:07:55.000+0000', 'Resolved', ''],
#  ['AIRFLOW-1000',
#   'Blocker',
#   '2017-03-17T19:35:10.000+0000',
#   'Closed',
#   '1.8.0'],
#  ['AIRFLOW-1001',
#   'Blocker',
#   '2017-03-17T20:33:07.000+0000',
#   'Closed',
#   '1.8.0 1.9.0'],
#  ['AIRFLOW-1002',
#   'Major',
#   '2017-03-17T20:42:13.000+0000',
#   'Resolved',
#   '1.8.0 2.0.0'],
#  ['AIRFLOW-1003',
#   'Major',
#   '2017-03-17T21:12:19.000+0000',
#   'Open',
#   '1.8.0 1.9.0'],
#  ['AIRFLOW-1004', 'Major', '2017-03-17T21:18:54.000+0000', 'Resolved', ''],
#  ['AIRFLOW-1005',
#   'Minor',
#   '2017-03-17T22:04:38.000+0000',
#   'Resolved',
#   '1.8.0'],
#  ['AIRFLOW-1006',
#   'Minor',
#   '2017-03-17T22:08:48.000+0000',
#   'Reopened',
#   '1.8.0'],
#  ['AIRFLOW-1007', 'Major', '2017-03-18T03:09:45.000+0000', 'Resolved', ''],
#  ...]

# %%
#Importing Pandas to download the data as csv file
import pandas as pd

# %%
#The column names for our dataframe(finally our csv file)
col_names=['key','priority','created','status','version']

# %%
#Creating a Panda Dataframe
final_df=pd.DataFrame(final_data,columns=col_names)

# %%
#Final dataframe
final_df
# Out:
#                key priority  ...    status                             version
# 0        AIRFLOW-1    Major  ...  Resolved
# 1        AIRFLOW-6    Major  ...    Closed
# 2        AIRFLOW-7    Minor  ...    Closed
# 3        AIRFLOW-9    Major  ...    Closed
# 4       AIRFLOW-10    Major  ...    Closed
# ...            ...      ...  ...       ...                                 ...
# 7033  AIRFLOW-7117    Minor  ...  Resolved  1.10.5 1.10.6 1.10.7 1.10.8 1.10.9
# 7034  AIRFLOW-7118    Minor  ...  Resolved  1.10.5 1.10.6 1.10.7 1.10.8 1.10.9
# 7035  AIRFLOW-7119    Minor  ...      Open                              1.10.9
# 7036  AIRFLOW-7120  Blocker  ...      Open                             1.10.10
# 7037  AIRFLOW-7121    Major  ...      Open                             1.10.10
#
# [7038 rows x 5 columns]

# %%
#Saving the data from dataframe to csv file
final_df.to_csv("airflow_interface.csv")
